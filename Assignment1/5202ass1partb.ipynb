# %% [markdown]
# ## Parb B

# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.mongodb.spark:mongo-spark-connector_2.11:2.4.0 pyspark-shell'
from pyspark.sql import SparkSession # Spark SQL
from pyspark import SparkContext # Sparkfrom datetime import datetime
from pyspark.sql.functions import col, udf 
from pyspark.sql.types import DateType
from datetime import datetime
from pyspark.sql import SQLContext
from pyspark.sql.functions import year, month, dayofmonth
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 1

# %%
sc = SparkContext.getOrCreate() # create spark context

# %%
if (sc is None):
    sc = SparkContext(master="local[*]")
spark = SparkSession(sparkContext=sc)\
        .builder\
        .appName("MongoDB and Apache Spark Data Visualization")\
        .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.11:2.4.0")\
        .config("spark.mongodb.input.uri", "mongodb://127.0.0.1/fit5202_db.wk05_titanic_coll")\
        .config("spark.mongodb.output.uri", "mongodb://127.0.0.1/fit5202_db.wk05_titanic_coll")\
        .getOrCreate()

# %% [markdown]
# ### Step 2

# %%
crime_df = spark.read.csv('Crime_Statistics_SA_2010_present.csv', header=True, inferSchema=True) # read crime stats csv

# %%
crime_df.take(5)
# Out:
# [Row(Reported Date='1/07/2010', Suburb - Incident='ADELAIDE', Postcode - Incident='5000', Offence Level 1 Description='OFFENCES AGAINST PROPERTY', Offence Level 2 Description='FRAUD DECEPTION AND RELATED OFFENCES', Offence Level 3 Description='Obtain benefit by deception', Offence Count=2),
#  Row(Reported Date='1/07/2010', Suburb - Incident='ADELAIDE', Postcode - Incident='5000', Offence Level 1 Description='OFFENCES AGAINST PROPERTY', Offence Level 2 Description='PROPERTY DAMAGE AND ENVIRONMENTAL', Offence Level 3 Description='Other property damage and environmental', Offence Count=2),
#  Row(Reported Date='1/07/2010', Suburb - Incident='ADELAIDE', Postcode - Incident='5000', Offence Level 1 Description='OFFENCES AGAINST PROPERTY', Offence Level 2 Description='SERIOUS CRIMINAL TRESPASS', Offence Level 3 Description='SCT - Non Residence', Offence Count=1),
#  Row(Reported Date='1/07/2010', Suburb - Incident='ADELAIDE', Postcode - Incident='5000', Offence Level 1 Description='OFFENCES AGAINST PROPERTY', Offence Level 2 Description='THEFT AND RELATED OFFENCES', Offence Level 3 Description='Other theft', Offence Count=6),
#  Row(Reported Date='1/07/2010', Suburb - Incident='ADELAIDE', Postcode - Incident='5000', Offence Level 1 Description='OFFENCES AGAINST PROPERTY', Offence Level 2 Description='THEFT AND RELATED OFFENCES', Offence Level 3 Description='Theft from shop', Offence Count=3)]

# %% [markdown]
# ### Step 3

# %%
crime_df.write.format("com.mongodb.spark.sql.DefaultSource").mode("overwrite").save() #write to mongodb

# %%
crime_df.show()
# Out:
# +-------------+-----------------+-------------------+---------------------------+---------------------------+---------------------------+-------------+
# |Reported Date|Suburb - Incident|Postcode - Incident|Offence Level 1 Description|Offence Level 2 Description|Offence Level 3 Description|Offence Count|
# +-------------+-----------------+-------------------+---------------------------+---------------------------+---------------------------+-------------+
# |    1/07/2010|         ADELAIDE|               5000|       OFFENCES AGAINST ...|       FRAUD DECEPTION A...|       Obtain benefit by...|            2|
# |    1/07/2010|         ADELAIDE|               5000|       OFFENCES AGAINST ...|       PROPERTY DAMAGE A...|       Other property da...|            2|
# |    1/07/2010|         ADELAIDE|               5000|       OFFENCES AGAINST ...|       SERIOUS CRIMINAL ...|        SCT - Non Residence|            1|
# |    1/07/2010|         ADELAIDE|               5000|       OFFENCES AGAINST ...|       THEFT AND RELATED...|                Other theft|            6|
# |    1/07/2010|         ADELAIDE|               5000|       OFFENCES AGAINST ...|       THEFT AND RELATED...|            Theft from shop|            3|
# |    1/07/2010|         ADELAIDE|               5000|       OFFENCES AGAINST ...|       ACTS INTENDED TO ...|             Common Assault|            2|
# |    1/07/2010|         ALBERTON|               5014|       OFFENCES AGAINST ...|       PROPERTY DAMAGE A...|       Other property da...|            1|
# |    1/07/2010|          ALDGATE|               5154|       OFFENCES AGAINST ...|       THEFT AND RELATED...|                Other theft|            1|
# |    1/07/2010|           ALFORD|               5555|       OFFENCES AGAINST ...|       THEFT AND RELATED...|                Other theft|            1|
# |    1/07/2010|            AMATA|               5724|       OFFENCES AGAINST ...|       PROPERTY DAMAGE A...|       Property damage b...|            1|
# |    1/07/2010|            AMATA|               5724|       OFFENCES AGAINST ...|       ACTS INTENDED TO ...|       Serious Assault r...|            1|
# |    1/07/2010|     ANDREWS FARM|               5114|       OFFENCES AGAINST ...|       PROPERTY DAMAGE A...|       Other property da...|            1|
# |    1/07/2010|       ASCOT PARK|               5043|       OFFENCES AGAINST ...|       FRAUD DECEPTION A...|       Obtain benefit by...|            1|
# |    1/07/2010|       ATHELSTONE|               5076|       OFFENCES AGAINST ...|       PROPERTY DAMAGE A...|       Other property da...|            1|
# |    1/07/2010|           AUBURN|               5451|       OFFENCES AGAINST ...|       SERIOUS CRIMINAL ...|            SCT - Residence|            1|
# |    1/07/2010|           BELAIR|               5052|       OFFENCES AGAINST ...|       SERIOUS CRIMINAL ...|            SCT - Residence|            1|
# |    1/07/2010|         BIRDWOOD|               5234|       OFFENCES AGAINST ...|       SERIOUS CRIMINAL ...|        SCT - Non Residence|            1|
# |    1/07/2010|       BIRKENHEAD|               5015|       OFFENCES AGAINST ...|       ACTS INTENDED TO ...|             Common Assault|            1|
# |    1/07/2010|      BLAIR ATHOL|               5084|       OFFENCES AGAINST ...|       PROPERTY DAMAGE A...|       Other property da...|            1|
# |    1/07/2010|      BLAIR ATHOL|               5084|       OFFENCES AGAINST ...|       THEFT AND RELATED...|       Theft from motor ...|            1|
# +-------------+-----------------+-------------------+---------------------------+---------------------------+---------------------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Step 4

# %%
crime_df_from_mongodb = spark.read.format("com.mongodb.spark.sql.DefaultSource").load() #read from mongodb

# %%
crime_df_from_mongodb.printSchema()
# Out:
# root
#  |-- Offence Count: integer (nullable = true)
#  |-- Offence Level 1 Description: string (nullable = true)
#  |-- Offence Level 2 Description: string (nullable = true)
#  |-- Offence Level 3 Description: string (nullable = true)
#  |-- Postcode - Incident: string (nullable = true)
#  |-- Reported Date: string (nullable = true)
#  |-- Suburb - Incident: string (nullable = true)
#  |-- _id: struct (nullable = true)
#  |    |-- oid: string (nullable = true)

# %%
offencecount = crime_df_from_mongodb.groupBy('Offence Count', 'Reported Date').count().sort('Reported Date', ascending=False)

# %% [markdown]
# ### Step 5

# %%
offencecount.collect()
# Out:
# [Row(Offence Count=3, Reported Date='9/12/2018', count=6),
#  Row(Offence Count=6, Reported Date='9/12/2018', count=1),
#  Row(Offence Count=2, Reported Date='9/12/2018', count=25),
#  Row(Offence Count=5, Reported Date='9/12/2018', count=1),
#  Row(Offence Count=1, Reported Date='9/12/2018', count=180),
#  Row(Offence Count=5, Reported Date='9/12/2016', count=1),
#  Row(Offence Count=4, Reported Date='9/12/2016', count=2),
#  Row(Offence Count=1, Reported Date='9/12/2016', count=216),
#  Row(Offence Count=3, Reported Date='9/12/2016', count=7),
#  Row(Offence Count=2, Reported Date='9/12/2016', count=28),
#  Row(Offence Count=6, Reported Date='9/12/2015', count=1),
#  Row(Offence Count=4, Reported Date='9/12/2015', count=2),
#  Row(Offence Count=3, Reported Date='9/12/2015', count=4),
#  Row(Offence Count=1, Reported Date='9/12/2015', count=235),
#  Row(Offence Count=2, Reported Date='9/12/2015', count=27),
#  Row(Offence Count=2, Reported Date='9/12/2014', count=21),
#  Row(Offence Count=1, Reported Date='9/12/2014', count=241),
#  Row(Offence Count=3, Reported Date='9/12/2014', count=4),
#  Row(Offence Count=1, Reported Date='9/12/2013', count=259),
#  Row(Offence Count=5, Reported Date='9/12/2013', count=2),
#  Row(Offence Count=4, Reported Date='9/12/2013', count=2),
#  Row(Offence Count=2, Reported Date='9/12/2013', count=25),
#  Row(Offence Count=3, Reported Date='9/12/2013', count=7),
#  Row(Offence Count=5, Reported Date='9/12/2012', count=1),
#  Row(Offence Count=4, Reported Date='9/12/2012', count=1),
#  Row(Offence Count=2, Reported Date='9/12/2012', count=15),
#  Row(Offence Count=7, Reported Date='9/12/2012', count=1),
#  Row(Offence Count=1, Reported Date='9/12/2012', count=232),
#  Row(Offence Count=3, Reported Date='9/12/2012', count=4),
#  Row(Offence Count=5, Reported Date='9/12/2011', count=1),
#  Row(Offence Count=1, Reported Date='9/12/2011', count=244),
#  Row(Offence Count=2, Reported Date='9/12/2011', count=24),
#  Row(Offence Count=4, Reported Date='9/12/2011', count=3),
#  Row(Offence Count=3, Reported Date='9/12/2011', count=5),
#  Row(Offence Count=6, Reported Date='9/12/2010', count=1),
#  Row(Offence Count=1, Reported Date='9/12/2010', count=261),
#  Row(Offence Count=7, Reported Date='9/12/2010', count=1),
#  Row(Offence Count=5, Reported Date='9/12/2010', count=1),
#  Row(Offence Count=4, Reported Date='9/12/2010', count=1),
#  Row(Offence Count=3, Reported Date='9/12/2010', count=1),
#  Row(Offence Count=2, Reported Date='9/12/2010', count=28),
#  Row(Offence Count=2, Reported Date='9/11/2018', count=27),
#  Row(Offence Count=3, Reported Date='9/11/2018', count=6),
#  Row(Offence Count=5, Reported Date='9/11/2018', count=2),
#  Row(Offence Count=1, Reported Date='9/11/2018', count=213),
#  Row(Offence Count=4, Reported Date='9/11/2018', count=3),
#  Row(Offence Count=1, Reported Date='9/11/2016', count=229),
#  Row(Offence Count=7, Reported Date='9/11/2016', count=1),
#  Row(Offence Count=4, Reported Date='9/11/2016', count=1),
#  Row(Offence Count=2, Reported Date='9/11/2016', count=27),
#  Row(Offence Count=3, Reported Date='9/11/2016', count=2),
#  Row(Offence Count=2, Reported Date='9/11/2015', count=34),
#  Row(Offence Count=1, Reported Date='9/11/2015', count=278),
#  Row(Offence Count=4, Reported Date='9/11/2015', count=2),
#  Row(Offence Count=3, Reported Date='9/11/2015', count=5),
#  Row(Offence Count=4, Reported Date='9/11/2014', count=1),
#  Row(Offence Count=2, Reported Date='9/11/2014', count=22),
#  Row(Offence Count=1, Reported Date='9/11/2014', count=162),
#  Row(Offence Count=7, Reported Date='9/11/2014', count=1),
#  Row(Offence Count=3, Reported Date='9/11/2014', count=3),
#  Row(Offence Count=2, Reported Date='9/11/2013', count=17),
#  Row(Offence Count=1, Reported Date='9/11/2013', count=209),
#  Row(Offence Count=3, Reported Date='9/11/2013', count=5),
#  Row(Offence Count=4, Reported Date='9/11/2013', count=2),
#  Row(Offence Count=1, Reported Date='9/11/2012', count=244),
#  Row(Offence Count=3, Reported Date='9/11/2012', count=5),
#  Row(Offence Count=4, Reported Date='9/11/2012', count=3),
#  Row(Offence Count=6, Reported Date='9/11/2012', count=2),
#  Row(Offence Count=2, Reported Date='9/11/2012', count=18),
#  Row(Offence Count=8, Reported Date='9/11/2011', count=1),
#  Row(Offence Count=1, Reported Date='9/11/2011', count=245),
#  Row(Offence Count=4, Reported Date='9/11/2011', count=1),
#  Row(Offence Count=5, Reported Date='9/11/2011', count=2),
#  Row(Offence Count=2, Reported Date='9/11/2011', count=32),
#  Row(Offence Count=3, Reported Date='9/11/2011', count=4),
#  Row(Offence Count=9, Reported Date='9/11/2010', count=1),
#  Row(Offence Count=2, Reported Date='9/11/2010', count=28),
#  Row(Offence Count=3, Reported Date='9/11/2010', count=5),
#  Row(Offence Count=1, Reported Date='9/11/2010', count=269),
#  Row(Offence Count=4, Reported Date='9/11/2010', count=2),
#  Row(Offence Count=5, Reported Date='9/11/2010', count=1),
#  Row(Offence Count=6, Reported Date='9/11/2010', count=1),
#  Row(Offence Count=7, Reported Date='9/10/2018', count=1),
#  Row(Offence Count=3, Reported Date='9/10/2018', count=3),
#  Row(Offence Count=2, Reported Date='9/10/2018', count=29),
#  Row(Offence Count=1, Reported Date='9/10/2018', count=264),
#  Row(Offence Count=5, Reported Date='9/10/2016', count=2),
#  Row(Offence Count=1, Reported Date='9/10/2016', count=190),
#  Row(Offence Count=4, Reported Date='9/10/2016', count=1),
#  Row(Offence Count=2, Reported Date='9/10/2016', count=17),
#  Row(Offence Count=3, Reported Date='9/10/2016', count=6),
#  Row(Offence Count=4, Reported Date='9/10/2015', count=1),
#  Row(Offence Count=2, Reported Date='9/10/2015', count=21),
#  Row(Offence Count=1, Reported Date='9/10/2015', count=250),
#  Row(Offence Count=3, Reported Date='9/10/2015', count=4),
#  Row(Offence Count=2, Reported Date='9/10/2014', count=17),
#  Row(Offence Count=7, Reported Date='9/10/2014', count=1),
#  Row(Offence Count=1, Reported Date='9/10/2014', count=207),
#  Row(Offence Count=3, Reported Date='9/10/2014', count=6),
#  Row(Offence Count=4, Reported Date='9/10/2014', count=1),
#  Row(Offence Count=7, Reported Date='9/10/2013', count=2),
#  Row(Offence Count=1, Reported Date='9/10/2013', count=293),
#  Row(Offence Count=3, Reported Date='9/10/2013', count=6),
#  Row(Offence Count=2, Reported Date='9/10/2013', count=23),
#  Row(Offence Count=6, Reported Date='9/10/2013', count=1),
#  Row(Offence Count=3, Reported Date='9/10/2012', count=3),
#  Row(Offence Count=5, Reported Date='9/10/2012', count=1),
#  Row(Offence Count=2, Reported Date='9/10/2012', count=27),
#  Row(Offence Count=6, Reported Date='9/10/2012', count=1),
#  Row(Offence Count=1, Reported Date='9/10/2012', count=262),
#  Row(Offence Count=4, Reported Date='9/10/2012', count=1),
#  Row(Offence Count=3, Reported Date='9/10/2011', count=7),
#  Row(Offence Count=4, Reported Date='9/10/2011', count=3),
#  Row(Offence Count=5, Reported Date='9/10/2011', count=1),
#  Row(Offence Count=1, Reported Date='9/10/2011', count=215),
#  Row(Offence Count=2, Reported Date='9/10/2011', count=24),
#  Row(Offence Count=7, Reported Date='9/10/2011', count=1),
#  Row(Offence Count=6, Reported Date='9/10/2011', count=1),
#  Row(Offence Count=2, Reported Date='9/10/2010', count=21),
#  Row(Offence Count=3, Reported Date='9/10/2010', count=8),
#  Row(Offence Count=5, Reported Date='9/10/2010', count=1),
#  Row(Offence Count=7, Reported Date='9/10/2010', count=1),
#  Row(Offence Count=4, Reported Date='9/10/2010', count=2),
#  Row(Offence Count=1, Reported Date='9/10/2010', count=230),
#  Row(Offence Count=6, Reported Date='9/10/2010', count=1),
#  Row(Offence Count=3, Reported Date='9/09/2018', count=6),
#  Row(Offence Count=1, Reported Date='9/09/2018', count=223),
#  Row(Offence Count=2, Reported Date='9/09/2018', count=23),
#  Row(Offence Count=3, Reported Date='9/09/2016', count=5),
#  Row(Offence Count=1, Reported Date='9/09/2016', count=230),
#  Row(Offence Count=2, Reported Date='9/09/2016', count=21),
#  Row(Offence Count=2, Reported Date='9/09/2015', count=20),
#  Row(Offence Count=5, Reported Date='9/09/2015', count=2),
#  Row(Offence Count=4, Reported Date='9/09/2015', count=1),
#  Row(Offence Count=1, Reported Date='9/09/2015', count=244),
#  Row(Offence Count=4, Reported Date='9/09/2014', count=1),
#  Row(Offence Count=3, Reported Date='9/09/2014', count=3),
#  Row(Offence Count=1, Reported Date='9/09/2014', count=232),
#  Row(Offence Count=2, Reported Date='9/09/2014', count=28),
#  Row(Offence Count=4, Reported Date='9/09/2013', count=1),
#  Row(Offence Count=2, Reported Date='9/09/2013', count=31),
#  Row(Offence Count=3, Reported Date='9/09/2013', count=3),
#  Row(Offence Count=6, Reported Date='9/09/2013', count=2),
#  Row(Offence Count=1, Reported Date='9/09/2013', count=253),
#  Row(Offence Count=4, Reported Date='9/09/2012', count=2),
#  Row(Offence Count=3, Reported Date='9/09/2012', count=4),
#  Row(Offence Count=1, Reported Date='9/09/2012', count=194),
#  Row(Offence Count=5, Reported Date='9/09/2012', count=2),
#  Row(Offence Count=2, Reported Date='9/09/2012', count=18),
#  Row(Offence Count=11, Reported Date='9/09/2012', count=1),
#  Row(Offence Count=2, Reported Date='9/09/2011', count=19),
#  Row(Offence Count=4, Reported Date='9/09/2011', count=1),
#  Row(Offence Count=5, Reported Date='9/09/2011', count=1),
#  Row(Offence Count=1, Reported Date='9/09/2011', count=242),
#  Row(Offence Count=3, Reported Date='9/09/2011', count=7),
#  Row(Offence Count=3, Reported Date='9/09/2010', count=5),
#  Row(Offence Count=5, Reported Date='9/09/2010', count=1),
#  Row(Offence Count=10, Reported Date='9/09/2010', count=1),
#  Row(Offence Count=4, Reported Date='9/09/2010', count=1),
#  Row(Offence Count=1, Reported Date='9/09/2010', count=266),
#  Row(Offence Count=2, Reported Date='9/09/2010', count=24),
#  Row(Offence Count=4, Reported Date='9/08/2018', count=3),
#  Row(Offence Count=2, Reported Date='9/08/2018', count=15),
#  Row(Offence Count=6, Reported Date='9/08/2018', count=1),
#  Row(Offence Count=3, Reported Date='9/08/2018', count=9),
#  Row(Offence Count=5, Reported Date='9/08/2018', count=2),
#  Row(Offence Count=1, Reported Date='9/08/2018', count=230),
#  Row(Offence Count=4, Reported Date='9/08/2016', count=4),
#  Row(Offence Count=8, Reported Date='9/08/2016', count=1),
#  Row(Offence Count=5, Reported Date='9/08/2016', count=1),
#  Row(Offence Count=2, Reported Date='9/08/2016', count=23),
#  Row(Offence Count=1, Reported Date='9/08/2016', count=218),
#  Row(Offence Count=6, Reported Date='9/08/2016', count=1),
#  Row(Offence Count=3, Reported Date='9/08/2016', count=6),
#  Row(Offence Count=1, Reported Date='9/08/2015', count=181),
#  Row(Offence Count=4, Reported Date='9/08/2015', count=2),
#  Row(Offence Count=2, Reported Date='9/08/2015', count=10),
#  Row(Offence Count=3, Reported Date='9/08/2015', count=5),
#  Row(Offence Count=1, Reported Date='9/08/2014', count=176),
#  Row(Offence Count=2, Reported Date='9/08/2014', count=23),
#  Row(Offence Count=3, Reported Date='9/08/2014', count=2),
#  Row(Offence Count=3, Reported Date='9/08/2013', count=3),
#  Row(Offence Count=4, Reported Date='9/08/2013', count=2),
#  Row(Offence Count=2, Reported Date='9/08/2013', count=23),
#  Row(Offence Count=1, Reported Date='9/08/2013', count=229),
#  Row(Offence Count=1, Reported Date='9/08/2012', count=219),
#  Row(Offence Count=2, Reported Date='9/08/2012', count=19),
#  Row(Offence Count=3, Reported Date='9/08/2012', count=10),
#  Row(Offence Count=4, Reported Date='9/08/2012', count=3),
#  Row(Offence Count=2, Reported Date='9/08/2011', count=18),
#  Row(Offence Count=1, Reported Date='9/08/2011', count=221),
#  Row(Offence Count=4, Reported Date='9/08/2011', count=1),
#  Row(Offence Count=3, Reported Date='9/08/2011', count=4),
#  Row(Offence Count=4, Reported Date='9/08/2010', count=1),
#  Row(Offence Count=2, Reported Date='9/08/2010', count=37),
#  Row(Offence Count=6, Reported Date='9/08/2010', count=1),
#  Row(Offence Count=1, Reported Date='9/08/2010', count=288),
#  Row(Offence Count=5, Reported Date='9/08/2010', count=1),
#  Row(Offence Count=3, Reported Date='9/08/2010', count=5),
#  Row(Offence Count=5, Reported Date='9/07/2018', count=2),
#  Row(Offence Count=3, Reported Date='9/07/2018', count=3),
#  Row(Offence Count=4, Reported Date='9/07/2018', count=3),
#  Row(Offence Count=2, Reported Date='9/07/2018', count=25),
#  Row(Offence Count=1, Reported Date='9/07/2018', count=262),
#  Row(Offence Count=2, Reported Date='9/07/2016', count=12),
#  Row(Offence Count=1, Reported Date='9/07/2016', count=177),
#  Row(Offence Count=3, Reported Date='9/07/2016', count=3),
#  Row(Offence Count=2, Reported Date='9/07/2015', count=23),
#  Row(Offence Count=4, Reported Date='9/07/2015', count=2),
#  Row(Offence Count=1, Reported Date='9/07/2015', count=211),
#  Row(Offence Count=5, Reported Date='9/07/2015', count=1),
#  Row(Offence Count=3, Reported Date='9/07/2015', count=8),
#  Row(Offence Count=2, Reported Date='9/07/2014', count=24),
#  Row(Offence Count=4, Reported Date='9/07/2014', count=2),
#  Row(Offence Count=1, Reported Date='9/07/2014', count=185),
#  Row(Offence Count=6, Reported Date='9/07/2014', count=1),
#  Row(Offence Count=3, Reported Date='9/07/2014', count=5),
#  Row(Offence Count=3, Reported Date='9/07/2013', count=4),
#  Row(Offence Count=1, Reported Date='9/07/2013', count=226),
#  Row(Offence Count=2, Reported Date='9/07/2013', count=19),
#  Row(Offence Count=6, Reported Date='9/07/2013', count=1),
#  Row(Offence Count=2, Reported Date='9/07/2012', count=20),
#  Row(Offence Count=7, Reported Date='9/07/2012', count=1),
#  Row(Offence Count=1, Reported Date='9/07/2012', count=246),
#  Row(Offence Count=3, Reported Date='9/07/2012', count=6),
#  Row(Offence Count=4, Reported Date='9/07/2012', count=1),
#  Row(Offence Count=3, Reported Date='9/07/2011', count=7),
#  Row(Offence Count=1, Reported Date='9/07/2011', count=227),
#  Row(Offence Count=6, Reported Date='9/07/2011', count=2),
#  Row(Offence Count=5, Reported Date='9/07/2011', count=1),
#  Row(Offence Count=2, Reported Date='9/07/2011', count=26),
#  Row(Offence Count=4, Reported Date='9/07/2010', count=1),
#  Row(Offence Count=2, Reported Date='9/07/2010', count=22),
#  Row(Offence Count=5, Reported Date='9/07/2010', count=1),
#  Row(Offence Count=3, Reported Date='9/07/2010', count=2),
#  Row(Offence Count=6, Reported Date='9/07/2010', count=3),
#  Row(Offence Count=1, Reported Date='9/07/2010', count=244),
#  Row(Offence Count=5, Reported Date='9/06/2017', count=1),
#  Row(Offence Count=3, Reported Date='9/06/2017', count=2),
#  Row(Offence Count=1, Reported Date='9/06/2017', count=190),
#  Row(Offence Count=2, Reported Date='9/06/2017', count=18),
#  Row(Offence Count=4, Reported Date='9/06/2017', count=1),
#  Row(Offence Count=2, Reported Date='9/06/2016', count=21),
#  Row(Offence Count=1, Reported Date='9/06/2016', count=213),
#  Row(Offence Count=7, Reported Date='9/06/2016', count=1),
#  Row(Offence Count=3, Reported Date='9/06/2016', count=4),
#  Row(Offence Count=7, Reported Date='9/06/2015', count=1),
#  Row(Offence Count=2, Reported Date='9/06/2015', count=22),
#  Row(Offence Count=1, Reported Date='9/06/2015', count=270),
#  Row(Offence Count=5, Reported Date='9/06/2015', count=2),
#  Row(Offence Count=4, Reported Date='9/06/2015', count=2),
#  Row(Offence Count=3, Reported Date='9/06/2015', count=7),
#  Row(Offence Count=2, Reported Date='9/06/2014', count=15),
#  Row(Offence Count=1, Reported Date='9/06/2014', count=185),
#  Row(Offence Count=4, Reported Date='9/06/2014', count=2),
#  Row(Offence Count=3, Reported Date='9/06/2014', count=4),
#  Row(Offence Count=4, Reported Date='9/06/2013', count=1),
#  Row(Offence Count=6, Reported Date='9/06/2013', count=1),
#  Row(Offence Count=2, Reported Date='9/06/2013', count=18),
#  Row(Offence Count=8, Reported Date='9/06/2013', count=1),
#  Row(Offence Count=1, Reported Date='9/06/2013', count=190),
#  Row(Offence Count=3, Reported Date='9/06/2013', count=7),
#  Row(Offence Count=2, Reported Date='9/06/2012', count=17),
#  Row(Offence Count=6, Reported Date='9/06/2012', count=2),
#  Row(Offence Count=1, Reported Date='9/06/2012', count=181),
#  Row(Offence Count=4, Reported Date='9/06/2012', count=2),
#  Row(Offence Count=3, Reported Date='9/06/2012', count=3),
#  Row(Offence Count=2, Reported Date='9/06/2011', count=25),
#  Row(Offence Count=3, Reported Date='9/06/2011', count=6),
#  Row(Offence Count=8, Reported Date='9/06/2011', count=1),
#  Row(Offence Count=1, Reported Date='9/06/2011', count=243),
#  Row(Offence Count=4, Reported Date='9/06/2011', count=2),
#  Row(Offence Count=5, Reported Date='9/06/2011', count=1),
#  Row(Offence Count=6, Reported Date='9/06/2011', count=2),
#  Row(Offence Count=3, Reported Date='9/05/2017', count=2),
#  Row(Offence Count=2, Reported Date='9/05/2017', count=23),
#  Row(Offence Count=1, Reported Date='9/05/2017', count=188),
#  Row(Offence Count=4, Reported Date='9/05/2017', count=1),
#  Row(Offence Count=6, Reported Date='9/05/2017', count=1),
#  Row(Offence Count=5, Reported Date='9/05/2016', count=2),
#  Row(Offence Count=4, Reported Date='9/05/2016', count=3),
#  Row(Offence Count=3, Reported Date='9/05/2016', count=6),
#  Row(Offence Count=2, Reported Date='9/05/2016', count=22),
#  Row(Offence Count=1, Reported Date='9/05/2016', count=226),
#  Row(Offence Count=6, Reported Date='9/05/2015', count=2),
#  Row(Offence Count=3, Reported Date='9/05/2015', count=6),
#  Row(Offence Count=2, Reported Date='9/05/2015', count=23),
#  Row(Offence Count=1, Reported Date='9/05/2015', count=205),
#  Row(Offence Count=4, Reported Date='9/05/2014', count=2),
#  Row(Offence Count=1, Reported Date='9/05/2014', count=210),
#  Row(Offence Count=3, Reported Date='9/05/2014', count=7),
#  Row(Offence Count=2, Reported Date='9/05/2014', count=12),
#  Row(Offence Count=8, Reported Date='9/05/2014', count=1),
#  Row(Offence Count=1, Reported Date='9/05/2013', count=249),
#  Row(Offence Count=2, Reported Date='9/05/2013', count=24),
#  Row(Offence Count=4, Reported Date='9/05/2013', count=1),
#  Row(Offence Count=3, Reported Date='9/05/2013', count=4),
#  Row(Offence Count=6, Reported Date='9/05/2012', count=1),
#  Row(Offence Count=1, Reported Date='9/05/2012', count=244),
#  Row(Offence Count=2, Reported Date='9/05/2012', count=32),
#  Row(Offence Count=5, Reported Date='9/05/2012', count=1),
#  Row(Offence Count=3, Reported Date='9/05/2012', count=5),
#  Row(Offence Count=5, Reported Date='9/05/2011', count=1),
#  Row(Offence Count=3, Reported Date='9/05/2011', count=5),
#  Row(Offence Count=6, Reported Date='9/05/2011', count=1),
#  Row(Offence Count=1, Reported Date='9/05/2011', count=297),
#  Row(Offence Count=2, Reported Date='9/05/2011', count=38),
#  Row(Offence Count=4, Reported Date='9/05/2011', count=4),
#  Row(Offence Count=1, Reported Date='9/04/2017', count=194),
#  Row(Offence Count=3, Reported Date='9/04/2017', count=6),
#  Row(Offence Count=2, Reported Date='9/04/2017', count=25),
#  Row(Offence Count=7, Reported Date='9/04/2017', count=1),
#  Row(Offence Count=4, Reported Date='9/04/2017', count=1),
#  Row(Offence Count=4, Reported Date='9/04/2016', count=1),
#  Row(Offence Count=1, Reported Date='9/04/2016', count=181),
#  Row(Offence Count=3, Reported Date='9/04/2016', count=3),
#  Row(Offence Count=2, Reported Date='9/04/2016', count=21),
#  Row(Offence Count=3, Reported Date='9/04/2015', count=2),
#  Row(Offence Count=2, Reported Date='9/04/2015', count=16),
#  Row(Offence Count=1, Reported Date='9/04/2015', count=207),
#  Row(Offence Count=5, Reported Date='9/04/2015', count=1),
#  Row(Offence Count=4, Reported Date='9/04/2015', count=1),
#  Row(Offence Count=2, Reported Date='9/04/2014', count=17),
#  Row(Offence Count=1, Reported Date='9/04/2014', count=202),
#  Row(Offence Count=4, Reported Date='9/04/2014', count=1),
#  Row(Offence Count=3, Reported Date='9/04/2014', count=2),
#  Row(Offence Count=5, Reported Date='9/04/2013', count=1),
#  Row(Offence Count=1, Reported Date='9/04/2013', count=204),
#  Row(Offence Count=2, Reported Date='9/04/2013', count=26),
#  Row(Offence Count=3, Reported Date='9/04/2013', count=6),
#  Row(Offence Count=4, Reported Date='9/04/2013', count=2),
#  Row(Offence Count=1, Reported Date='9/04/2012', count=183),
#  Row(Offence Count=3, Reported Date='9/04/2012', count=1),
#  Row(Offence Count=2, Reported Date='9/04/2012', count=25),
#  Row(Offence Count=4, Reported Date='9/04/2012', count=1),
#  Row(Offence Count=4, Reported Date='9/04/2011', count=2),
#  Row(Offence Count=8, Reported Date='9/04/2011', count=1),
#  Row(Offence Count=2, Reported Date='9/04/2011', count=24),
#  Row(Offence Count=5, Reported Date='9/04/2011', count=1),
#  Row(Offence Count=1, Reported Date='9/04/2011', count=232),
#  Row(Offence Count=3, Reported Date='9/04/2011', count=9),
#  Row(Offence Count=4, Reported Date='9/03/2019', count=2),
#  Row(Offence Count=2, Reported Date='9/03/2019', count=21),
#  Row(Offence Count=1, Reported Date='9/03/2019', count=199),
#  Row(Offence Count=3, Reported Date='9/03/2019', count=6),
#  Row(Offence Count=3, Reported Date='9/03/2017', count=2),
#  Row(Offence Count=1, Reported Date='9/03/2017', count=212),
#  Row(Offence Count=5, Reported Date='9/03/2017', count=1),
#  Row(Offence Count=4, Reported Date='9/03/2017', count=2),
#  Row(Offence Count=2, Reported Date='9/03/2017', count=22),
#  Row(Offence Count=5, Reported Date='9/03/2016', count=1),
#  Row(Offence Count=4, Reported Date='9/03/2016', count=2),
#  Row(Offence Count=1, Reported Date='9/03/2016', count=211),
#  Row(Offence Count=2, Reported Date='9/03/2016', count=35),
#  Row(Offence Count=3, Reported Date='9/03/2016', count=3),
#  Row(Offence Count=1, Reported Date='9/03/2015', count=213),
#  Row(Offence Count=3, Reported Date='9/03/2015', count=5),
#  Row(Offence Count=4, Reported Date='9/03/2015', count=2),
#  Row(Offence Count=2, Reported Date='9/03/2015', count=21),
#  Row(Offence Count=2, Reported Date='9/03/2014', count=20),
#  Row(Offence Count=1, Reported Date='9/03/2014', count=202),
#  Row(Offence Count=3, Reported Date='9/03/2014', count=4),
#  Row(Offence Count=4, Reported Date='9/03/2014', count=3),
#  Row(Offence Count=5, Reported Date='9/03/2014', count=2),
#  Row(Offence Count=2, Reported Date='9/03/2013', count=30),
#  Row(Offence Count=1, Reported Date='9/03/2013', count=189),
#  Row(Offence Count=3, Reported Date='9/03/2013', count=5),
#  Row(Offence Count=9, Reported Date='9/03/2013', count=1),
#  Row(Offence Count=5, Reported Date='9/03/2013', count=1),
#  Row(Offence Count=4, Reported Date='9/03/2012', count=3),
#  Row(Offence Count=1, Reported Date='9/03/2012', count=247),
#  Row(Offence Count=5, Reported Date='9/03/2012', count=1),
#  Row(Offence Count=2, Reported Date='9/03/2012', count=24),
#  Row(Offence Count=3, Reported Date='9/03/2012', count=8),
#  Row(Offence Count=3, Reported Date='9/03/2011', count=4),
#  Row(Offence Count=1, Reported Date='9/03/2011', count=256),
#  Row(Offence Count=4, Reported Date='9/03/2011', count=1),
#  Row(Offence Count=2, Reported Date='9/03/2011', count=23),
#  Row(Offence Count=3, Reported Date='9/02/2019', count=6),
#  Row(Offence Count=4, Reported Date='9/02/2019', count=2),
#  Row(Offence Count=2, Reported Date='9/02/2019', count=23),
#  Row(Offence Count=1, Reported Date='9/02/2019', count=216),
#  Row(Offence Count=6, Reported Date='9/02/2019', count=1),
#  Row(Offence Count=3, Reported Date='9/02/2017', count=6),
#  Row(Offence Count=5, Reported Date='9/02/2017', count=2),
#  Row(Offence Count=2, Reported Date='9/02/2017', count=15),
#  Row(Offence Count=4, Reported Date='9/02/2017', count=2),
#  Row(Offence Count=1, Reported Date='9/02/2017', count=232),
#  Row(Offence Count=5, Reported Date='9/02/2016', count=1),
#  Row(Offence Count=4, Reported Date='9/02/2016', count=1),
#  Row(Offence Count=2, Reported Date='9/02/2016', count=25),
#  Row(Offence Count=10, Reported Date='9/02/2016', count=1),
#  Row(Offence Count=3, Reported Date='9/02/2016', count=6),
#  Row(Offence Count=1, Reported Date='9/02/2016', count=235),
#  Row(Offence Count=1, Reported Date='9/02/2015', count=258),
#  Row(Offence Count=2, Reported Date='9/02/2015', count=39),
#  Row(Offence Count=4, Reported Date='9/02/2015', count=2),
#  Row(Offence Count=7, Reported Date='9/02/2015', count=1),
#  Row(Offence Count=3, Reported Date='9/02/2015', count=5),
#  Row(Offence Count=9, Reported Date='9/02/2015', count=1),
#  Row(Offence Count=1, Reported Date='9/02/2014', count=182),
#  Row(Offence Count=4, Reported Date='9/02/2014', count=1),
#  Row(Offence Count=3, Reported Date='9/02/2014', count=7),
#  Row(Offence Count=2, Reported Date='9/02/2014', count=23),
#  Row(Offence Count=5, Reported Date='9/02/2014', count=1),
#  Row(Offence Count=2, Reported Date='9/02/2013', count=23),
#  Row(Offence Count=1, Reported Date='9/02/2013', count=199),
#  Row(Offence Count=3, Reported Date='9/02/2013', count=1),
#  Row(Offence Count=7, Reported Date='9/02/2013', count=2),
#  Row(Offence Count=4, Reported Date='9/02/2013', count=2),
#  Row(Offence Count=3, Reported Date='9/02/2012', count=5),
#  Row(Offence Count=2, Reported Date='9/02/2012', count=22),
#  Row(Offence Count=6, Reported Date='9/02/2012', count=2),
#  Row(Offence Count=1, Reported Date='9/02/2012', count=223),
#  Row(Offence Count=5, Reported Date='9/02/2012', count=1),
#  Row(Offence Count=3, Reported Date='9/02/2011', count=6),
#  Row(Offence Count=4, Reported Date='9/02/2011', count=2),
#  Row(Offence Count=2, Reported Date='9/02/2011', count=26),
#  Row(Offence Count=1, Reported Date='9/02/2011', count=269),
#  Row(Offence Count=2, Reported Date='9/01/2019', count=27),
#  Row(Offence Count=4, Reported Date='9/01/2019', count=3),
#  Row(Offence Count=5, Reported Date='9/01/2019', count=1),
#  Row(Offence Count=1, Reported Date='9/01/2019', count=227),
#  Row(Offence Count=7, Reported Date='9/01/2019', count=1),
#  Row(Offence Count=3, Reported Date='9/01/2019', count=7),
#  Row(Offence Count=3, Reported Date='9/01/2017', count=6),
#  Row(Offence Count=1, Reported Date='9/01/2017', count=262),
#  Row(Offence Count=5, Reported Date='9/01/2017', count=2),
#  Row(Offence Count=2, Reported Date='9/01/2017', count=36),
#  Row(Offence Count=4, Reported Date='9/01/2017', count=5),
#  Row(Offence Count=2, Reported Date='9/01/2016', count=15),
#  Row(Offence Count=1, Reported Date='9/01/2016', count=191),
#  Row(Offence Count=3, Reported Date='9/01/2016', count=5),
#  Row(Offence Count=6, Reported Date='9/01/2016', count=1),
#  Row(Offence Count=3, Reported Date='9/01/2015', count=8),
#  Row(Offence Count=4, Reported Date='9/01/2015', count=1),
#  Row(Offence Count=2, Reported Date='9/01/2015', count=29),
#  Row(Offence Count=1, Reported Date='9/01/2015', count=221),
#  Row(Offence Count=6, Reported Date='9/01/2014', count=1),
#  Row(Offence Count=1, Reported Date='9/01/2014', count=197),
#  Row(Offence Count=2, Reported Date='9/01/2014', count=19),
#  Row(Offence Count=1, Reported Date='9/01/2013', count=238),
#  Row(Offence Count=5, Reported Date='9/01/2013', count=1),
#  Row(Offence Count=6, Reported Date='9/01/2013', count=1),
#  Row(Offence Count=4, Reported Date='9/01/2013', count=3),
#  Row(Offence Count=3, Reported Date='9/01/2013', count=5),
#  Row(Offence Count=2, Reported Date='9/01/2013', count=26),
#  Row(Offence Count=4, Reported Date='9/01/2012', count=2),
#  Row(Offence Count=5, Reported Date='9/01/2012', count=3),
#  Row(Offence Count=6, Reported Date='9/01/2012', count=1),
#  Row(Offence Count=2, Reported Date='9/01/2012', count=28),
#  Row(Offence Count=3, Reported Date='9/01/2012', count=11),
#  Row(Offence Count=1, Reported Date='9/01/2012', count=291),
#  Row(Offence Count=1, Reported Date='9/01/2011', count=248),
#  Row(Offence Count=3, Reported Date='9/01/2011', count=4),
#  Row(Offence Count=4, Reported Date='9/01/2011', count=1),
#  Row(Offence Count=2, Reported Date='9/01/2011', count=23),
#  Row(Offence Count=5, Reported Date='9/01/2011', count=1),
#  Row(Offence Count=5, Reported Date='8/12/2018', count=2),
#  Row(Offence Count=1, Reported Date='8/12/2018', count=195),
#  Row(Offence Count=2, Reported Date='8/12/2018', count=23),
#  Row(Offence Count=4, Reported Date='8/12/2018', count=2),
#  Row(Offence Count=6, Reported Date='8/12/2018', count=1),
#  Row(Offence Count=3, Reported Date='8/12/2018', count=3),
#  Row(Offence Count=7, Reported Date='8/12/2016', count=1),
#  Row(Offence Count=4, Reported Date='8/12/2016', count=1),
#  Row(Offence Count=2, Reported Date='8/12/2016', count=30),
#  Row(Offence Count=3, Reported Date='8/12/2016', count=7),
#  Row(Offence Count=1, Reported Date='8/12/2016', count=249),
#  Row(Offence Count=4, Reported Date='8/12/2015', count=3),
#  Row(Offence Count=3, Reported Date='8/12/2015', count=5),
#  Row(Offence Count=2, Reported Date='8/12/2015', count=28),
#  Row(Offence Count=1, Reported Date='8/12/2015', count=228),
#  Row(Offence Count=2, Reported Date='8/12/2014', count=25),
#  Row(Offence Count=1, Reported Date='8/12/2014', count=295),
#  Row(Offence Count=3, Reported Date='8/12/2014', count=2),
#  Row(Offence Count=4, Reported Date='8/12/2014', count=1),
#  Row(Offence Count=6, Reported Date='8/12/2013', count=2),
#  Row(Offence Count=2, Reported Date='8/12/2013', count=25),
#  Row(Offence Count=1, Reported Date='8/12/2013', count=210),
#  Row(Offence Count=4, Reported Date='8/12/2013', count=2),
#  Row(Offence Count=3, Reported Date='8/12/2013', count=8),
#  Row(Offence Count=5, Reported Date='8/12/2012', count=3),
#  Row(Offence Count=1, Reported Date='8/12/2012', count=234),
#  Row(Offence Count=4, Reported Date='8/12/2012', count=3),
#  Row(Offence Count=2, Reported Date='8/12/2012', count=23),
#  Row(Offence Count=13, Reported Date='8/12/2012', count=1),
#  Row(Offence Count=4, Reported Date='8/12/2011', count=3),
#  Row(Offence Count=2, Reported Date='8/12/2011', count=17),
#  Row(Offence Count=3, Reported Date='8/12/2011', count=8),
#  Row(Offence Count=5, Reported Date='8/12/2011', count=1),
#  Row(Offence Count=1, Reported Date='8/12/2011', count=245),
#  Row(Offence Count=7, Reported Date='8/12/2011', count=2),
#  Row(Offence Count=1, Reported Date='8/12/2010', count=276),
#  Row(Offence Count=3, Reported Date='8/12/2010', count=7),
#  Row(Offence Count=2, Reported Date='8/12/2010', count=32),
#  Row(Offence Count=4, Reported Date='8/12/2010', count=1),
#  Row(Offence Count=4, Reported Date='8/11/2018', count=3),
#  Row(Offence Count=3, Reported Date='8/11/2018', count=3),
#  Row(Offence Count=2, Reported Date='8/11/2018', count=29),
#  Row(Offence Count=6, Reported Date='8/11/2018', count=1),
#  Row(Offence Count=1, Reported Date='8/11/2018', count=245),
#  Row(Offence Count=3, Reported Date='8/11/2016', count=3),
#  Row(Offence Count=2, Reported Date='8/11/2016', count=30),
#  Row(Offence Count=1, Reported Date='8/11/2016', count=262),
#  Row(Offence Count=4, Reported Date='8/11/2016', count=3),
#  Row(Offence Count=6, Reported Date='8/11/2016', count=1),
#  Row(Offence Count=2, Reported Date='8/11/2015', count=19),
#  Row(Offence Count=6, Reported Date='8/11/2015', count=1),
#  Row(Offence Count=1, Reported Date='8/11/2015', count=204),
#  Row(Offence Count=3, Reported Date='8/11/2015', count=2),
#  Row(Offence Count=8, Reported Date='8/11/2015', count=1),
#  Row(Offence Count=1, Reported Date='8/11/2014', count=200),
#  Row(Offence Count=4, Reported Date='8/11/2014', count=1),
#  Row(Offence Count=2, Reported Date='8/11/2014', count=16),
#  Row(Offence Count=3, Reported Date='8/11/2014', count=2),
#  Row(Offence Count=7, Reported Date='8/11/2014', count=1),
#  Row(Offence Count=6, Reported Date='8/11/2014', count=1),
#  Row(Offence Count=2, Reported Date='8/11/2013', count=20),
#  Row(Offence Count=6, Reported Date='8/11/2013', count=1),
#  Row(Offence Count=1, Reported Date='8/11/2013', count=208),
#  Row(Offence Count=3, Reported Date='8/11/2013', count=2),
#  Row(Offence Count=4, Reported Date='8/11/2013', count=2),
#  Row(Offence Count=3, Reported Date='8/11/2012', count=4),
#  Row(Offence Count=5, Reported Date='8/11/2012', count=1),
#  Row(Offence Count=7, Reported Date='8/11/2012', count=1),
#  Row(Offence Count=1, Reported Date='8/11/2012', count=232),
#  Row(Offence Count=2, Reported Date='8/11/2012', count=29),
#  Row(Offence Count=4, Reported Date='8/11/2012', count=1),
#  Row(Offence Count=1, Reported Date='8/11/2011', count=276),
#  Row(Offence Count=9, Reported Date='8/11/2011', count=1),
#  Row(Offence Count=2, Reported Date='8/11/2011', count=30),
#  Row(Offence Count=3, Reported Date='8/11/2011', count=2),
#  Row(Offence Count=2, Reported Date='8/11/2010', count=37),
#  Row(Offence Count=7, Reported Date='8/11/2010', count=1),
#  Row(Offence Count=4, Reported Date='8/11/2010', count=2),
#  Row(Offence Count=1, Reported Date='8/11/2010', count=270),
#  Row(Offence Count=3, Reported Date='8/11/2010', count=11),
#  Row(Offence Count=5, Reported Date='8/11/2010', count=2),
#  Row(Offence Count=4, Reported Date='8/10/2018', count=2),
#  Row(Offence Count=11, Reported Date='8/10/2018', count=1),
#  Row(Offence Count=3, Reported Date='8/10/2018', count=12),
#  Row(Offence Count=2, Reported Date='8/10/2018', count=29),
#  Row(Offence Count=1, Reported Date='8/10/2018', count=286),
#  Row(Offence Count=2, Reported Date='8/10/2016', count=18),
#  Row(Offence Count=1, Reported Date='8/10/2016', count=205),
#  Row(Offence Count=3, Reported Date='8/10/2016', count=3),
#  Row(Offence Count=4, Reported Date='8/10/2016', count=1),
#  Row(Offence Count=6, Reported Date='8/10/2016', count=1),
#  Row(Offence Count=3, Reported Date='8/10/2015', count=8),
#  Row(Offence Count=11, Reported Date='8/10/2015', count=1),
#  Row(Offence Count=1, Reported Date='8/10/2015', count=227),
#  Row(Offence Count=2, Reported Date='8/10/2015', count=24),
#  Row(Offence Count=5, Reported Date='8/10/2015', count=1),
#  Row(Offence Count=3, Reported Date='8/10/2014', count=3),
#  Row(Offence Count=1, Reported Date='8/10/2014', count=221),
#  Row(Offence Count=2, Reported Date='8/10/2014', count=18),
#  Row(Offence Count=4, Reported Date='8/10/2014', count=2),
#  Row(Offence Count=7, Reported Date='8/10/2013', count=1),
#  Row(Offence Count=2, Reported Date='8/10/2013', count=34),
#  Row(Offence Count=9, Reported Date='8/10/2013', count=1),
#  Row(Offence Count=3, Reported Date='8/10/2013', count=1),
#  Row(Offence Count=4, Reported Date='8/10/2013', count=3),
#  Row(Offence Count=1, Reported Date='8/10/2013', count=284),
#  Row(Offence Count=7, Reported Date='8/10/2012', count=1),
#  Row(Offence Count=3, Reported Date='8/10/2012', count=1),
#  Row(Offence Count=2, Reported Date='8/10/2012', count=32),
#  Row(Offence Count=6, Reported Date='8/10/2012', count=1),
#  Row(Offence Count=1, Reported Date='8/10/2012', count=325),
#  Row(Offence Count=5, Reported Date='8/10/2012', count=1),
#  Row(Offence Count=3, Reported Date='8/10/2011', count=5),
#  Row(Offence Count=5, Reported Date='8/10/2011', count=1),
#  Row(Offence Count=1, Reported Date='8/10/2011', count=215),
#  Row(Offence Count=4, Reported Date='8/10/2011', count=3),
#  Row(Offence Count=2, Reported Date='8/10/2011', count=23),
#  Row(Offence Count=8, Reported Date='8/10/2010', count=1),
#  Row(Offence Count=1, Reported Date='8/10/2010', count=255),
#  Row(Offence Count=5, Reported Date='8/10/2010', count=2),
#  Row(Offence Count=3, Reported Date='8/10/2010', count=5),
#  Row(Offence Count=2, Reported Date='8/10/2010', count=35),
#  Row(Offence Count=1, Reported Date='8/09/2018', count=178),
#  Row(Offence Count=2, Reported Date='8/09/2018', count=21),
#  Row(Offence Count=3, Reported Date='8/09/2018', count=3),
#  Row(Offence Count=7, Reported Date='8/09/2018', count=1),
#  Row(Offence Count=2, Reported Date='8/09/2016', count=24),
#  Row(Offence Count=5, Reported Date='8/09/2016', count=2),
#  Row(Offence Count=1, Reported Date='8/09/2016', count=232),
#  Row(Offence Count=3, Reported Date='8/09/2016', count=3),
#  Row(Offence Count=3, Reported Date='8/09/2015', count=3),
#  Row(Offence Count=2, Reported Date='8/09/2015', count=24),
#  Row(Offence Count=6, Reported Date='8/09/2015', count=1),
#  Row(Offence Count=7, Reported Date='8/09/2015', count=1),
#  Row(Offence Count=4, Reported Date='8/09/2015', count=3),
#  Row(Offence Count=1, Reported Date='8/09/2015', count=228),
#  Row(Offence Count=4, Reported Date='8/09/2014', count=1),
#  Row(Offence Count=3, Reported Date='8/09/2014', count=7),
#  Row(Offence Count=1, Reported Date='8/09/2014', count=250),
#  Row(Offence Count=2, Reported Date='8/09/2014', count=28),
#  Row(Offence Count=1, Reported Date='8/09/2013', count=194),
#  Row(Offence Count=3, Reported Date='8/09/2013', count=4),
#  Row(Offence Count=2, Reported Date='8/09/2013', count=30),
#  Row(Offence Count=14, Reported Date='8/09/2013', count=1),
#  Row(Offence Count=4, Reported Date='8/09/2013', count=2),
#  Row(Offence Count=6, Reported Date='8/09/2013', count=1),
#  Row(Offence Count=2, Reported Date='8/09/2012', count=19),
#  Row(Offence Count=5, Reported Date='8/09/2012', count=1),
#  Row(Offence Count=4, Reported Date='8/09/2012', count=1),
#  Row(Offence Count=1, Reported Date='8/09/2012', count=231),
#  Row(Offence Count=6, Reported Date='8/09/2012', count=1),
#  Row(Offence Count=3, Reported Date='8/09/2012', count=5),
#  Row(Offence Count=4, Reported Date='8/09/2011', count=3),
#  Row(Offence Count=1, Reported Date='8/09/2011', count=240),
#  Row(Offence Count=2, Reported Date='8/09/2011', count=31),
#  Row(Offence Count=6, Reported Date='8/09/2011', count=2),
#  Row(Offence Count=3, Reported Date='8/09/2011', count=6),
#  Row(Offence Count=1, Reported Date='8/09/2010', count=227),
#  Row(Offence Count=6, Reported Date='8/09/2010', count=1),
#  Row(Offence Count=2, Reported Date='8/09/2010', count=22),
#  Row(Offence Count=3, Reported Date='8/09/2010', count=6),
#  Row(Offence Count=4, Reported Date='8/09/2010', count=2),
#  Row(Offence Count=5, Reported Date='8/09/2010', count=2),
#  Row(Offence Count=1, Reported Date='8/08/2018', count=223),
#  Row(Offence Count=2, Reported Date='8/08/2018', count=23),
#  Row(Offence Count=4, Reported Date='8/08/2018', count=4),
#  Row(Offence Count=7, Reported Date='8/08/2018', count=1),
#  Row(Offence Count=3, Reported Date='8/08/2018', count=6),
#  Row(Offence Count=1, Reported Date='8/08/2016', count=268),
#  Row(Offence Count=4, Reported Date='8/08/2016', count=2),
#  Row(Offence Count=2, Reported Date='8/08/2016', count=29),
#  Row(Offence Count=3, Reported Date='8/08/2016', count=3),
#  Row(Offence Count=1, Reported Date='8/08/2015', count=206),
#  Row(Offence Count=5, Reported Date='8/08/2015', count=1),
#  Row(Offence Count=3, Reported Date='8/08/2015', count=3),
#  Row(Offence Count=4, Reported Date='8/08/2015', count=1),
#  Row(Offence Count=2, Reported Date='8/08/2015', count=25),
#  Row(Offence Count=6, Reported Date='8/08/2014', count=1),
#  Row(Offence Count=1, Reported Date='8/08/2014', count=204),
#  Row(Offence Count=3, Reported Date='8/08/2014', count=7),
#  Row(Offence Count=2, Reported Date='8/08/2014', count=20),
#  Row(Offence Count=5, Reported Date='8/08/2014', count=1),
#  Row(Offence Count=5, Reported Date='8/08/2013', count=1),
#  Row(Offence Count=2, Reported Date='8/08/2013', count=22),
#  Row(Offence Count=4, Reported Date='8/08/2013', count=2),
#  Row(Offence Count=1, Reported Date='8/08/2013', count=203),
#  Row(Offence Count=3, Reported Date='8/08/2013', count=4),
#  Row(Offence Count=2, Reported Date='8/08/2012', count=17),
#  Row(Offence Count=4, Reported Date='8/08/2012', count=2),
#  Row(Offence Count=1, Reported Date='8/08/2012', count=203),
#  Row(Offence Count=3, Reported Date='8/08/2012', count=3),
#  Row(Offence Count=1, Reported Date='8/08/2011', count=265),
#  Row(Offence Count=5, Reported Date='8/08/2011', count=1),
#  Row(Offence Count=4, Reported Date='8/08/2011', count=1),
#  Row(Offence Count=3, Reported Date='8/08/2011', count=7),
#  Row(Offence Count=2, Reported Date='8/08/2011', count=34),
#  Row(Offence Count=6, Reported Date='8/08/2010', count=1),
#  Row(Offence Count=7, Reported Date='8/08/2010', count=1),
#  Row(Offence Count=3, Reported Date='8/08/2010', count=6),
#  Row(Offence Count=2, Reported Date='8/08/2010', count=22),
#  Row(Offence Count=12, Reported Date='8/08/2010', count=1),
#  Row(Offence Count=1, Reported Date='8/08/2010', count=220),
#  Row(Offence Count=3, Reported Date='8/07/2018', count=3),
#  Row(Offence Count=7, Reported Date='8/07/2018', count=1),
#  Row(Offence Count=2, Reported Date='8/07/2018', count=16),
#  Row(Offence Count=1, Reported Date='8/07/2018', count=201),
#  Row(Offence Count=4, Reported Date='8/07/2018', count=3),
#  Row(Offence Count=2, Reported Date='8/07/2016', count=24),
#  Row(Offence Count=3, Reported Date='8/07/2016', count=5),
#  Row(Offence Count=1, Reported Date='8/07/2016', count=200),
#  Row(Offence Count=5, Reported Date='8/07/2015', count=1),
#  Row(Offence Count=2, Reported Date='8/07/2015', count=21),
#  Row(Offence Count=3, Reported Date='8/07/2015', count=5),
#  Row(Offence Count=1, Reported Date='8/07/2015', count=211),
#  Row(Offence Count=4, Reported Date='8/07/2015', count=1),
#  Row(Offence Count=6, Reported Date='8/07/2015', count=1),
#  Row(Offence Count=4, Reported Date='8/07/2014', count=1),
#  Row(Offence Count=3, Reported Date='8/07/2014', count=4),
#  Row(Offence Count=1, Reported Date='8/07/2014', count=209),
#  Row(Offence Count=6, Reported Date='8/07/2014', count=1),
#  Row(Offence Count=2, Reported Date='8/07/2014', count=24),
#  Row(Offence Count=1, Reported Date='8/07/2013', count=248),
#  Row(Offence Count=3, Reported Date='8/07/2013', count=6),
#  Row(Offence Count=4, Reported Date='8/07/2013', count=1),
#  Row(Offence Count=2, Reported Date='8/07/2013', count=28),
#  Row(Offence Count=2, Reported Date='8/07/2012', count=15),
#  Row(Offence Count=1, Reported Date='8/07/2012', count=173),
#  Row(Offence Count=4, Reported Date='8/07/2012', count=2),
#  Row(Offence Count=7, Reported Date='8/07/2012', count=1),
#  Row(Offence Count=3, Reported Date='8/07/2012', count=3),
#  Row(Offence Count=6, Reported Date='8/07/2012', count=1),
#  Row(Offence Count=2, Reported Date='8/07/2011', count=19),
#  Row(Offence Count=1, Reported Date='8/07/2011', count=253),
#  Row(Offence Count=5, Reported Date='8/07/2011', count=1),
#  Row(Offence Count=7, Reported Date='8/07/2011', count=1),
#  Row(Offence Count=3, Reported Date='8/07/2011', count=5),
#  Row(Offence Count=6, Reported Date='8/07/2011', count=1),
#  Row(Offence Count=4, Reported Date='8/07/2010', count=2),
#  Row(Offence Count=1, Reported Date='8/07/2010', count=229),
#  Row(Offence Count=8, Reported Date='8/07/2010', count=1),
#  Row(Offence Count=3, Reported Date='8/07/2010', count=2),
#  Row(Offence Count=2, Reported Date='8/07/2010', count=27),
#  Row(Offence Count=5, Reported Date='8/06/2017', count=1),
#  Row(Offence Count=2, Reported Date='8/06/2017', count=28),
#  Row(Offence Count=7, Reported Date='8/06/2017', count=1),
#  Row(Offence Count=1, Reported Date='8/06/2017', count=200),
#  Row(Offence Count=4, Reported Date='8/06/2017', count=2),
#  Row(Offence Count=3, Reported Date='8/06/2017', count=3),
#  Row(Offence Count=2, Reported Date='8/06/2016', count=29),
#  Row(Offence Count=4, Reported Date='8/06/2016', count=3),
#  Row(Offence Count=3, Reported Date='8/06/2016', count=8),
#  Row(Offence Count=1, Reported Date='8/06/2016', count=229),
#  Row(Offence Count=5, Reported Date='8/06/2016', count=1),
#  Row(Offence Count=7, Reported Date='8/06/2016', count=1),
#  Row(Offence Count=2, Reported Date='8/06/2015', count=26),
#  Row(Offence Count=4, Reported Date='8/06/2015', count=2),
#  Row(Offence Count=1, Reported Date='8/06/2015', count=185),
#  Row(Offence Count=3, Reported Date='8/06/2015', count=6),
#  Row(Offence Count=5, Reported Date='8/06/2014', count=1),
#  Row(Offence Count=1, Reported Date='8/06/2014', count=174),
#  Row(Offence Count=3, Reported Date='8/06/2014', count=4),
#  Row(Offence Count=2, Reported Date='8/06/2014', count=13),
#  Row(Offence Count=3, Reported Date='8/06/2013', count=9),
#  Row(Offence Count=2, Reported Date='8/06/2013', count=24),
#  Row(Offence Count=7, Reported Date='8/06/2013', count=1),
#  Row(Offence Count=1, Reported Date='8/06/2013', count=201),
#  Row(Offence Count=2, Reported Date='8/06/2012', count=20),
#  Row(Offence Count=1, Reported Date='8/06/2012', count=233),
#  Row(Offence Count=11, Reported Date='8/06/2012', count=1),
#  Row(Offence Count=4, Reported Date='8/06/2012', count=1),
#  Row(Offence Count=3, Reported Date='8/06/2012', count=4),
#  Row(Offence Count=3, Reported Date='8/06/2011', count=2),
#  Row(Offence Count=6, Reported Date='8/06/2011', count=1),
#  Row(Offence Count=4, Reported Date='8/06/2011', count=2),
#  Row(Offence Count=2, Reported Date='8/06/2011', count=19),
#  Row(Offence Count=1, Reported Date='8/06/2011', count=201),
#  Row(Offence Count=4, Reported Date='8/05/2017', count=1),
#  Row(Offence Count=3, Reported Date='8/05/2017', count=3),
#  Row(Offence Count=2, Reported Date='8/05/2017', count=20),
#  Row(Offence Count=1, Reported Date='8/05/2017', count=230),
#  Row(Offence Count=2, Reported Date='8/05/2016', count=13),
#  Row(Offence Count=1, Reported Date='8/05/2016', count=180),
#  Row(Offence Count=5, Reported Date='8/05/2016', count=1),
#  Row(Offence Count=3, Reported Date='8/05/2016', count=4),
#  Row(Offence Count=4, Reported Date='8/05/2016', count=1),
#  Row(Offence Count=1, Reported Date='8/05/2015', count=222),
#  Row(Offence Count=3, Reported Date='8/05/2015', count=5),
#  Row(Offence Count=2, Reported Date='8/05/2015', count=22),
#  Row(Offence Count=4, Reported Date='8/05/2015', count=1),
#  Row(Offence Count=2, Reported Date='8/05/2014', count=16),
#  Row(Offence Count=4, Reported Date='8/05/2014', count=2),
#  Row(Offence Count=1, Reported Date='8/05/2014', count=184),
#  Row(Offence Count=3, Reported Date='8/05/2014', count=4),
#  Row(Offence Count=4, Reported Date='8/05/2013', count=2),
#  Row(Offence Count=1, Reported Date='8/05/2013', count=236),
#  Row(Offence Count=3, Reported Date='8/05/2013', count=2),
#  Row(Offence Count=2, Reported Date='8/05/2013', count=24),
#  Row(Offence Count=3, Reported Date='8/05/2012', count=8),
#  Row(Offence Count=2, Reported Date='8/05/2012', count=18),
#  Row(Offence Count=4, Reported Date='8/05/2012', count=3),
#  Row(Offence Count=1, Reported Date='8/05/2012', count=219),
#  Row(Offence Count=5, Reported Date='8/05/2012', count=2),
#  Row(Offence Count=3, Reported Date='8/05/2011', count=3),
#  Row(Offence Count=4, Reported Date='8/05/2011', count=2),
#  Row(Offence Count=2, Reported Date='8/05/2011', count=28),
#  Row(Offence Count=1, Reported Date='8/05/2011', count=197),
#  Row(Offence Count=8, Reported Date='8/05/2011', count=1),
#  Row(Offence Count=2, Reported Date='8/04/2017', count=12),
#  Row(Offence Count=1, Reported Date='8/04/2017', count=185),
#  Row(Offence Count=3, Reported Date='8/04/2017', count=2),
#  Row(Offence Count=5, Reported Date='8/04/2017', count=1),
#  Row(Offence Count=1, Reported Date='8/04/2016', count=225),
#  Row(Offence Count=8, Reported Date='8/04/2016', count=1),
#  Row(Offence Count=3, Reported Date='8/04/2016', count=4),
#  Row(Offence Count=4, Reported Date='8/04/2016', count=1),
#  Row(Offence Count=2, Reported Date='8/04/2016', count=27),
#  Row(Offence Count=6, Reported Date='8/04/2016', count=1),
#  Row(Offence Count=7, Reported Date='8/04/2016', count=1),
#  Row(Offence Count=2, Reported Date='8/04/2015', count=32),
#  Row(Offence Count=4, Reported Date='8/04/2015', count=1),
#  Row(Offence Count=3, Reported Date='8/04/2015', count=3),
#  Row(Offence Count=13, Reported Date='8/04/2015', count=1),
#  Row(Offence Count=15, Reported Date='8/04/2015', count=1),
#  Row(Offence Count=1, Reported Date='8/04/2015', count=207),
#  Row(Offence Count=3, Reported Date='8/04/2014', count=3),
#  Row(Offence Count=1, Reported Date='8/04/2014', count=179),
#  Row(Offence Count=4, Reported Date='8/04/2014', count=1),
#  Row(Offence Count=2, Reported Date='8/04/2014', count=23),
#  Row(Offence Count=3, Reported Date='8/04/2013', count=8),
#  Row(Offence Count=5, Reported Date='8/04/2013', count=2),
#  Row(Offence Count=1, Reported Date='8/04/2013', count=252),
#  Row(Offence Count=2, Reported Date='8/04/2013', count=24),
#  Row(Offence Count=2, Reported Date='8/04/2012', count=30),
#  Row(Offence Count=1, Reported Date='8/04/2012', count=201),
#  Row(Offence Count=4, Reported Date='8/04/2012', count=1),
#  Row(Offence Count=3, Reported Date='8/04/2012', count=9),
#  Row(Offence Count=4, Reported Date='8/04/2011', count=3),
#  Row(Offence Count=7, Reported Date='8/04/2011', count=1),
#  Row(Offence Count=1, Reported Date='8/04/2011', count=244),
#  Row(Offence Count=2, Reported Date='8/04/2011', count=28),
#  Row(Offence Count=3, Reported Date='8/04/2011', count=7),
#  Row(Offence Count=5, Reported Date='8/04/2011', count=2),
#  Row(Offence Count=1, Reported Date='8/03/2019', count=219),
#  Row(Offence Count=4, Reported Date='8/03/2019', count=4),
#  Row(Offence Count=2, Reported Date='8/03/2019', count=19),
#  Row(Offence Count=5, Reported Date='8/03/2019', count=1),
#  Row(Offence Count=3, Reported Date='8/03/2019', count=5),
#  Row(Offence Count=1, Reported Date='8/03/2017', count=217),
#  Row(Offence Count=3, Reported Date='8/03/2017', count=3),
#  Row(Offence Count=4, Reported Date='8/03/2017', count=1),
#  Row(Offence Count=2, Reported Date='8/03/2017', count=23),
#  Row(Offence Count=4, Reported Date='8/03/2016', count=2),
#  Row(Offence Count=2, Reported Date='8/03/2016', count=21),
#  Row(Offence Count=1, Reported Date='8/03/2016', count=219),
#  Row(Offence Count=3, Reported Date='8/03/2016', count=6),
#  Row(Offence Count=1, Reported Date='8/03/2015', count=194),
#  Row(Offence Count=2, Reported Date='8/03/2015', count=7),
#  Row(Offence Count=3, Reported Date='8/03/2015', count=4),
#  Row(Offence Count=8, Reported Date='8/03/2015', count=1),
#  Row(Offence Count=4, Reported Date='8/03/2014', count=3),
#  Row(Offence Count=5, Reported Date='8/03/2014', count=1),
#  Row(Offence Count=2, Reported Date='8/03/2014', count=19),
#  Row(Offence Count=1, Reported Date='8/03/2014', count=198),
#  Row(Offence Count=3, Reported Date='8/03/2014', count=2),
#  Row(Offence Count=3, Reported Date='8/03/2013', count=4),
#  Row(Offence Count=7, Reported Date='8/03/2013', count=1),
#  Row(Offence Count=4, Reported Date='8/03/2013', count=2),
#  Row(Offence Count=1, Reported Date='8/03/2013', count=230),
#  Row(Offence Count=2, Reported Date='8/03/2013', count=29),
#  Row(Offence Count=2, Reported Date='8/03/2012', count=23),
#  Row(Offence Count=5, Reported Date='8/03/2012', count=2),
#  Row(Offence Count=4, Reported Date='8/03/2012', count=1),
#  Row(Offence Count=3, Reported Date='8/03/2012', count=6),
#  Row(Offence Count=1, Reported Date='8/03/2012', count=242),
#  Row(Offence Count=3, Reported Date='8/03/2011', count=2),
#  Row(Offence Count=4, Reported Date='8/03/2011', count=2),
#  Row(Offence Count=2, Reported Date='8/03/2011', count=25),
#  Row(Offence Count=1, Reported Date='8/03/2011', count=244),
#  Row(Offence Count=5, Reported Date='8/03/2011', count=1),
#  Row(Offence Count=1, Reported Date='8/02/2019', count=214),
#  Row(Offence Count=2, Reported Date='8/02/2019', count=21),
#  Row(Offence Count=3, Reported Date='8/02/2019', count=6),
#  Row(Offence Count=5, Reported Date='8/02/2019', count=1),
#  Row(Offence Count=1, Reported Date='8/02/2017', count=222),
#  Row(Offence Count=3, Reported Date='8/02/2017', count=2),
#  Row(Offence Count=6, Reported Date='8/02/2017', count=2),
#  Row(Offence Count=2, Reported Date='8/02/2017', count=23),
#  Row(Offence Count=6, Reported Date='8/02/2016', count=1),
#  Row(Offence Count=1, Reported Date='8/02/2016', count=250),
#  Row(Offence Count=4, Reported Date='8/02/2016', count=2),
#  Row(Offence Count=3, Reported Date='8/02/2016', count=5),
#  Row(Offence Count=2, Reported Date='8/02/2016', count=23),
#  Row(Offence Count=1, Reported Date='8/02/2015', count=199),
#  Row(Offence Count=3, Reported Date='8/02/2015', count=4),
#  Row(Offence Count=5, Reported Date='8/02/2015', count=1),
#  Row(Offence Count=2, Reported Date='8/02/2015', count=19),
#  Row(Offence Count=4, Reported Date='8/02/2015', count=2),
#  Row(Offence Count=2, Reported Date='8/02/2014', count=29),
#  Row(Offence Count=1, Reported Date='8/02/2014', count=202),
#  Row(Offence Count=3, Reported Date='8/02/2014', count=6),
#  Row(Offence Count=5, Reported Date='8/02/2014', count=1),
#  Row(Offence Count=4, Reported Date='8/02/2014', count=3),
#  Row(Offence Count=6, Reported Date='8/02/2014', count=1),
#  Row(Offence Count=7, Reported Date='8/02/2014', count=1),
#  Row(Offence Count=6, Reported Date='8/02/2013', count=1),
#  Row(Offence Count=3, Reported Date='8/02/2013', count=5),
#  Row(Offence Count=1, Reported Date='8/02/2013', count=234),
#  Row(Offence Count=2, Reported Date='8/02/2013', count=23),
#  Row(Offence Count=4, Reported Date='8/02/2013', count=3),
#  Row(Offence Count=1, Reported Date='8/02/2012', count=244),
#  Row(Offence Count=4, Reported Date='8/02/2012', count=1),
#  Row(Offence Count=3, Reported Date='8/02/2012', count=3),
#  Row(Offence Count=2, Reported Date='8/02/2012', count=23),
#  Row(Offence Count=7, Reported Date='8/02/2012', count=1),
#  Row(Offence Count=2, Reported Date='8/02/2011', count=33),
#  Row(Offence Count=6, Reported Date='8/02/2011', count=1),
#  Row(Offence Count=5, Reported Date='8/02/2011', count=3),
#  Row(Offence Count=1, Reported Date='8/02/2011', count=277),
#  Row(Offence Count=3, Reported Date='8/02/2011', count=3),
#  Row(Offence Count=10, Reported Date='8/02/2011', count=1),
#  Row(Offence Count=4, Reported Date='8/02/2011', count=4),
#  Row(Offence Count=3, Reported Date='8/01/2019', count=2),
#  Row(Offence Count=6, Reported Date='8/01/2019', count=1),
#  Row(Offence Count=1, Reported Date='8/01/2019', count=265),
#  Row(Offence Count=2, Reported Date='8/01/2019', count=30),
#  Row(Offence Count=5, Reported Date='8/01/2017', count=1),
#  Row(Offence Count=4, Reported Date='8/01/2017', count=1),
#  Row(Offence Count=3, Reported Date='8/01/2017', count=9),
#  Row(Offence Count=1, Reported Date='8/01/2017', count=192),
#  Row(Offence Count=2, Reported Date='8/01/2017', count=21),
#  Row(Offence Count=4, Reported Date='8/01/2016', count=2),
#  Row(Offence Count=2, Reported Date='8/01/2016', count=20),
#  Row(Offence Count=3, Reported Date='8/01/2016', count=3),
#  Row(Offence Count=1, Reported Date='8/01/2016', count=248),
#  Row(Offence Count=2, Reported Date='8/01/2015', count=16),
#  Row(Offence Count=3, Reported Date='8/01/2015', count=8),
#  Row(Offence Count=1, Reported Date='8/01/2015', count=233),
#  Row(Offence Count=2, Reported Date='8/01/2014', count=19),
#  Row(Offence Count=1, Reported Date='8/01/2014', count=234),
#  Row(Offence Count=3, Reported Date='8/01/2014', count=5),
#  Row(Offence Count=3, Reported Date='8/01/2013', count=10),
#  Row(Offence Count=1, Reported Date='8/01/2013', count=274),
#  Row(Offence Count=6, Reported Date='8/01/2013', count=1),
#  Row(Offence Count=2, Reported Date='8/01/2013', count=24),
#  Row(Offence Count=3, Reported Date='8/01/2012', count=6),
#  Row(Offence Count=2, Reported Date='8/01/2012', count=25),
#  Row(Offence Count=1, Reported Date='8/01/2012', count=225),
#  Row(Offence Count=4, Reported Date='8/01/2012', count=3),
#  Row(Offence Count=5, Reported Date='8/01/2011', count=2),
#  Row(Offence Count=3, Reported Date='8/01/2011', count=1),
#  Row(Offence Count=1, Reported Date='8/01/2011', count=219),
#  Row(Offence Count=4, Reported Date='8/01/2011', count=2),
#  Row(Offence Count=2, Reported Date='8/01/2011', count=23),
#  Row(Offence Count=1, Reported Date='7/12/2018', count=237),
#  Row(Offence Count=2, Reported Date='7/12/2018', count=23),
#  Row(Offence Count=7, Reported Date='7/12/2016', count=1),
#  Row(Offence Count=2, Reported Date='7/12/2016', count=25),
#  Row(Offence Count=1, Reported Date='7/12/2016', count=228),
#  Row(Offence Count=3, Reported Date='7/12/2016', count=2),
#  Row(Offence Count=4, Reported Date='7/12/2016', count=2),
#  Row(Offence Count=5, Reported Date='7/12/2016', count=2),
#  Row(Offence Count=2, Reported Date='7/12/2015', count=25),
#  Row(Offence Count=11, Reported Date='7/12/2015', count=1),
#  Row(Offence Count=5, Reported Date='7/12/2015', count=1),
#  Row(Offence Count=4, Reported Date='7/12/2015', count=3),
#  Row(Offence Count=3, Reported Date='7/12/2015', count=7),
#  Row(Offence Count=1, Reported Date='7/12/2015', count=297),
#  Row(Offence Count=3, Reported Date='7/12/2014', count=7),
#  Row(Offence Count=8, Reported Date='7/12/2014', count=1),
#  Row(Offence Count=2, Reported Date='7/12/2014', count=19),
#  Row(Offence Count=1, Reported Date='7/12/2014', count=209),
#  Row(Offence Count=1, Reported Date='7/12/2013', count=196),
#  Row(Offence Count=5, Reported Date='7/12/2013', count=1),
#  Row(Offence Count=6, Reported Date='7/12/2013', count=1),
#  Row(Offence Count=4, Reported Date='7/12/2013', count=5),
#  Row(Offence Count=2, Reported Date='7/12/2013', count=18),
#  Row(Offence Count=3, Reported Date='7/12/2013', count=6),
#  Row(Offence Count=2, Reported Date='7/12/2012', count=31),
#  Row(Offence Count=1, Reported Date='7/12/2012', count=238),
#  Row(Offence Count=6, Reported Date='7/12/2012', count=1),
#  Row(Offence Count=4, Reported Date='7/12/2012', count=2),
#  Row(Offence Count=1, Reported Date='7/12/2011', count=260),
#  Row(Offence Count=4, Reported Date='7/12/2011', count=1),
#  Row(Offence Count=2, Reported Date='7/12/2011', count=23),
#  Row(Offence Count=5, Reported Date='7/12/2011', count=1),
#  Row(Offence Count=7, Reported Date='7/12/2011', count=1),
#  Row(Offence Count=3, Reported Date='7/12/2011', count=1),
#  Row(Offence Count=3, Reported Date='7/12/2010', count=6),
#  Row(Offence Count=1, Reported Date='7/12/2010', count=261),
#  Row(Offence Count=2, Reported Date='7/12/2010', count=30),
#  Row(Offence Count=5, Reported Date='7/11/2018', count=2),
#  Row(Offence Count=9, Reported Date='7/11/2018', count=1),
#  Row(Offence Count=1, Reported Date='7/11/2018', count=243),
#  Row(Offence Count=3, Reported Date='7/11/2018', count=5),
#  Row(Offence Count=2, Reported Date='7/11/2018', count=21),
#  Row(Offence Count=8, Reported Date='7/11/2018', count=1),
#  Row(Offence Count=12, Reported Date='7/11/2016', count=1),
#  Row(Offence Count=2, Reported Date='7/11/2016', count=26),
#  Row(Offence Count=7, Reported Date='7/11/2016', count=1),
#  Row(Offence Count=3, Reported Date='7/11/2016', count=6),
#  Row(Offence Count=1, Reported Date='7/11/2016', count=266),
#  Row(Offence Count=3, Reported Date='7/11/2015', count=5),
#  Row(Offence Count=1, Reported Date='7/11/2015', count=192),
#  Row(Offence Count=2, Reported Date='7/11/2015', count=23),
#  Row(Offence Count=3, Reported Date='7/11/2014', count=6),
#  Row(Offence Count=7, Reported Date='7/11/2014', count=1),
#  Row(Offence Count=4, Reported Date='7/11/2014', count=2),
#  Row(Offence Count=5, Reported Date='7/11/2014', count=1),
#  Row(Offence Count=1, Reported Date='7/11/2014', count=237),
#  Row(Offence Count=2, Reported Date='7/11/2014', count=32),
#  Row(Offence Count=2, Reported Date='7/11/2013', count=18),
#  Row(Offence Count=1, Reported Date='7/11/2013', count=209),
#  Row(Offence Count=3, Reported Date='7/11/2013', count=6),
#  Row(Offence Count=1, Reported Date='7/11/2012', count=255),
#  Row(Offence Count=2, Reported Date='7/11/2012', count=27),
#  Row(Offence Count=5, Reported Date='7/11/2012', count=1),
#  Row(Offence Count=3, Reported Date='7/11/2012', count=6),
#  Row(Offence Count=1, Reported Date='7/11/2011', count=282),
#  Row(Offence Count=4, Reported Date='7/11/2011', count=3),
#  Row(Offence Count=2, Reported Date='7/11/2011', count=39),
#  Row(Offence Count=3, Reported Date='7/11/2011', count=4),
#  Row(Offence Count=2, Reported Date='7/11/2010', count=19),
#  Row(Offence Count=3, Reported Date='7/11/2010', count=3),
#  Row(Offence Count=6, Reported Date='7/11/2010', count=1),
#  Row(Offence Count=4, Reported Date='7/11/2010', count=4),
#  Row(Offence Count=1, Reported Date='7/11/2010', count=222),
#  Row(Offence Count=1, Reported Date='7/10/2018', count=205),
#  Row(Offence Count=3, Reported Date='7/10/2018', count=6),
#  Row(Offence Count=4, Reported Date='7/10/2018', count=1),
#  Row(Offence Count=2, Reported Date='7/10/2018', count=19),
#  Row(Offence Count=1, Reported Date='7/10/2016', count=218),
#  Row(Offence Count=4, Reported Date='7/10/2016', count=2),
#  Row(Offence Count=3, Reported Date='7/10/2016', count=13),
#  Row(Offence Count=5, Reported Date='7/10/2016', count=1),
#  Row(Offence Count=11, Reported Date='7/10/2016', count=1),
#  Row(Offence Count=2, Reported Date='7/10/2016', count=32),
#  Row(Offence Count=2, Reported Date='7/10/2015', count=24),
#  Row(Offence Count=3, Reported Date='7/10/2015', count=2),
#  Row(Offence Count=1, Reported Date='7/10/2015', count=228),
#  Row(Offence Count=4, Reported Date='7/10/2015', count=1),
#  Row(Offence Count=4, Reported Date='7/10/2014', count=1),
#  Row(Offence Count=3, Reported Date='7/10/2014', count=7),
#  ...]

# %%
summarydf = crime_df_from_mongodb.select('Offence Count', 'Reported Date') # create sub dataframe

# %%
summarydf.describe().show() # describe
# Out:
# +-------+------------------+-------------+
# |summary|     Offence Count|Reported Date|
# +-------+------------------+-------------+
# |  count|            727407|       727407|
# |   mean|1.1715174585892079|         null|
# | stddev|0.5787050930378118|         null|
# |    min|                 1|    1/01/2011|
# |    max|                28|    9/12/2018|
# +-------+------------------+-------------+

# %% [markdown]
# ### Step 6

# %%
crime_df_from_mongodb.na.drop(subset=["Reported Date"]) # drop all empty dates
# Out:
# DataFrame[Offence Count: int, Offence Level 1 Description: string, Offence Level 2 Description: string, Offence Level 3 Description: string, Postcode - Incident: string, Reported Date: string, Suburb - Incident: string, _id: struct<oid:string>]

# %%
func =  udf (lambda x:  datetime.strptime(str(x), '%d/%m/%Y'), DateType()) #udf to convert to datetime

# dated_crime_df = crime_df.withColumn('Modified Reported Date', func(col('Reported Date')))

# join_Df1.filter(join_Df1.FirstName.isNotNull()).show

dated_crime_df = crime_df_from_mongodb.filter(crime_df_from_mongodb['Reported Date'].isNotNull()).withColumn('Modified Reported Date', func(col('Reported Date'))) # convert to datetime

# %%
dated_crime_df.collect()

# %% [markdown]
# ### Step 7

# %%
pipeline = [{ '$group': { '_id': { 'Level2Offence': '$Offence Level 2 Description' }, 'count': { '$sum': '$Offence Count' } } }]

# %%
level_2_offence_crime_df = spark.read.format("com.mongodb.spark.sql.DefaultSource").option("pipeline", pipeline).load()

# %%
level_2_offence_crime_df.count()

# %%
for row in level_2_offence_crime_df.toLocalIterator():
        print(row[0].Level2Offence)

# %%
dated_crime_df.filter(dated_crime_df['Offence Level 1 Description'] == "OFFENCES AGAINST THE PERSON").count()

# %%
tresspasses_crime_df = dated_crime_df.filter(dated_crime_df['Offence Level 2 Description'] == "SERIOUS CRIMINAL TRESPASS").filter(dated_crime_df['Offence Count'] > 1)

# %%
tresspasses_crime_df.count()

# %%
x1 = dated_crime_df.filter(dated_crime_df['Offence Level 1 Description'] == "OFFENCES AGAINST PROPERTY").count()
x2 = dated_crime_df.count()
(x1/x2)*100

# %% [markdown]
# ### Step 8

# %%
month = dated_crime_df.select(month('Modified Reported Date').alias('month'))

# %%
month.count()

# %%
month_count = month.groupBy('month').count().sort('month', ascending=False)

# %%
month_count.collect()

# %%
montharray = []
montharraycount = []
for x in month_count.toLocalIterator():
    montharray.append(x[0])
    montharraycount.append(x[1])

# %%
plt.plot(montharray, montharraycount)
plt.show()

# %%
year = dated_crime_df.select(year('Modified Reported Date').alias('year'))

# %%
year.take(5)

# %%
year.count()

# %%
year_count = year.groupBy('year').count().sort('year', ascending=True)

# %%
year_count.collect()

# %%
type(year_count)

# %%
yeararray = []
yeararraycount = []
for x in year_count.toLocalIterator():
    yeararray.append(x[0])
    yeararraycount.append(x[1])

# %%
plt.plot(yeararray, yeararraycount)
plt.show()
