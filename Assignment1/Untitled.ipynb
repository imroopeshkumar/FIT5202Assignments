# %%
from datetime import datetime
from pyspark.sql.functions import col, udf
from pyspark.sql.types import DateType
from pyspark.sql import SQLContext
from pyspark import SparkContext # Sparkfrom datetime import datetime

# %%
sc = SparkContext.getOrCreate()

# %%
sqlContext = SQLContext(sc)

# %%
df1 = sqlContext.createDataFrame([("11/25/1991","11/24/1991","11/30/1991"), 
                            ("1/25/1391","11/24/1992","11/30/1992")], schema=['first', 'second', 'third'])

# %%
df1.collect()
# Out:
# [Row(first='11/25/1991', second='11/24/1991', third='11/30/1991'),
#  Row(first='1/25/1391', second='11/24/1992', third='11/30/1992')]

# %%
func =  udf (lambda x: datetime.strptime(x, '%m/%d/%Y'), DateType())

# %%
df = df1.withColumn('test', func(col('first')))

# %%
df.collect()
# Out:
# [Row(first='11/25/1991', second='11/24/1991', third='11/30/1991', test=datetime.date(1991, 11, 25)),
#  Row(first='1/25/1391', second='11/24/1992', third='11/30/1992', test=datetime.date(1391, 1, 25))]
