# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt
import csv
import datetime as dt

def read_csv(fileName): #read csv file
    data = []
    cRows = csv.DictReader(open(fileName))
    for rows in cRows:
        data.append(rows)
    return data

def publish_message(producer_instance, topic_name, data): #Function to publish the message
    try:
        producer_instance.send(topic_name, data)
        print('Message published successfully')
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'memory' #Defining the topic name
    
    process_rows = read_csv('../Streaming_Linux_memory.csv') #reading the csv and getting a dictionary using a defined function
    
    print('Publishing records..')
    
    producer = connect_kafka_producer()
    
    data4 = [] #Initialising an empty list to store the data of machine 4
    data5 = [] #Initialising an empty list to store the data of machine 5
    data6 = [] #Initialising an empty list to store the data of machine 6
    data7 = [] #Initialising an empty list to store the data of machine 7
    data8 = [] #Initialising an empty list to store the data of machine 8
    
    for i in range(len(process_rows)): #casting correct datatypes
        process_rows[i]["sequence"] = int(process_rows[i]["sequence"])
        process_rows[i]["machine"] = int(process_rows[i]["machine"])
        process_rows[i]["PID"] = int(process_rows[i]["PID"])
        process_rows[i]["MINFLT"] = str(process_rows[i]["MINFLT"])
        process_rows[i]["MAJFLT"] = str(process_rows[i]["MAJFLT"])
        process_rows[i]["VSTEXT"] = str(process_rows[i]["VSTEXT"])
        process_rows[i]["VSIZE"] = float(process_rows[i]["VSIZE"])
        process_rows[i]["RSIZE"] = str(process_rows[i]["RSIZE"])
        process_rows[i]["VGROW"] = str(process_rows[i]["VGROW"])
        process_rows[i]["RGROW"] = str(process_rows[i]["RGROW"])
        process_rows[i]["MEM"] = float(process_rows[i]["MEM"])
        process_rows[i]["CMD"] = str(process_rows[i]["CMD"])
    
    for i in range(len(process_rows)): #splitting into machine lists
        if process_rows[i]["machine"] == 4:
            data4.append(process_rows[i])
        if process_rows[i]["machine"] == 5:
            data5.append(process_rows[i])
        if process_rows[i]["machine"] == 6:
            data6.append(process_rows[i])
        if process_rows[i]["machine"] == 7:
            data7.append(process_rows[i])
        if process_rows[i]["machine"] == 8:
            data8.append(process_rows[i])
            
    rowstart4 = 0 
    rowstart5 = 0
    rowstart6 = 0
    rowstart7 = 0
    rowstart8 = 0 
    
    data = [] #data to send
    
    
    while(True):
        
        
        rowcountx4 = random.randint(20,80) #get n random records 
        rowend4 = rowstart4 + rowcountx4 #get end index
        if rowend4 > len(data4)-1: #take data until endindex > len of datalist
            newdata4 = data4[rowstart4:len(data4)-1] 
            rowend4 = rowcountx4 - len(newdata4)-1 #get number of data we need from start
            rowstart4 = 0  #start from first sequence again
            newcountdata4 = data4[rowstart4:rowend4] #get remaining data from start
            for i in newcountdata4:
                newdata4.append(i)
        elif rowend4 == len(data4)-1: #if endindex = lastindex
            newdata4 = data4[rowstart4:rowend4]
            rowend4 = -1 #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata4 = data4[rowstart4:rowend4]
        rowstart4 = rowend4 + 1 #Reset the  next index of last index as the next start index
        
        rowcountx5 = random.randint(20,80) #Getting random X records for machine 5
        rowend5 = rowstart5 + rowcountx5 #Getting the end index
        if rowend5 > len(data5)-1: #If end index is greater than last index
            newdata5 = data5[rowstart5:len(data5)-1] #Take data till last index
            rowend5 = rowcountx5 - len(newdata5)-1 #get the number of how much more data we need from the start
            rowstart_5 = 0 #Start from the first sequence again
            newcountdata5 = data5[rowstart5:rowend5] #Get the remaining data from the start
            for i in newcountdata5:
                newdata5.append(i)
        elif rowend5 == len(data5)-1:  #If end index becomes equal to the last index
            newdata5 = data5[rowstart5:rowend5]
            rowend5 = -1 #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata5 = data5[rowstart5:rowend5]
        rowstart5 = rowend5 + 1 #Reset the  next index of last index as the next start index
        
        rowcountx6 = random.randint(20,80) #Getting random X records for machine 6
        rowend6 = rowstart6 + rowcountx6 #Getting the end index
        if rowend6 > len(data6)-1: #If end index is greater than last index
            newdata6 = data6[rowstart6:len(data6)-1] #Take data till last index
            rowend6 = rowcountx6 - len(newdata6)-1 #get the number of how much more data we need from the start
            rowstart6 = 0 #Start from the first sequence again
            newcountdata6 = data6[rowstart6:rowend6]#Get the remaining data from the start
            for i in newcountdata6:
                newdata6.append(i)
        elif rowend6 == len(data6)-1: #If end index becomes equal to the last index
            newdata6 = data6[rowstart6:rowend6]
            row_end_6 = -1 #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata6 = data6[rowstart6:rowend6]
        rowstart6 = rowend6 + 1 #Reset the  next index of last index as the next start index
        
        rowcountx7 = random.randint(20,80) #Getting random X records for machine 7
        rowend7 = rowstart7 + rowcountx7 #Getting the end index
        if rowend7 > len(data7)-1: #If end index is greater than last index
            newdata7 = data7[rowstart7:len(data7)-1] #Take data till last index
            rowend7 = rowcountx7 - len(newdata7)-1 #get the number of how much more data we need from the start
            rowstart7 = 0 #Start from the first sequence again
            newcountdata7 = data7[rowstart7:rowend7] #Get the remaining data from the start
            for i in newcountdata7:
                newdata7.append(i)
        elif rowend7 == len(data7)-1: #If end index becomes equal to the last index
            newdata7 = data7[rowstart7:rowend7]
            rowend7 = -1 #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata7 = data7[rowstart7:rowend7]
        rowstart7 = rowend7 + 1#Reset the  next index of last index as the next start index
        
        rowcountx8 = random.randint(20,80) #Getting random X records for machine 7
        rowend8 = rowstart8 + rowcountx8 #Getting the end index
        if rowend8 > len(data8)-1: #If end index is greater than last index
            newdata8 = data8[rowstart8:len(data8)-1] #Take data till last index
            rowend8 = rowcountx8 - len(newdata8)-1 #get the number of how much more data we need from the start
            rowstart8 = 0 #Start from the first sequence again
            newcountdata8 = data8[rowstart8:rowend8]  #Get the remaining data from the start
            for i in new_count_data8:
                newdata8.append(i)
        elif rowend8 == len(data8)-1: #If end index becomes equal to the last index
            newdata8 = data8[rowstart8:rowend8]
            rowend8 = -1 #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata8 = data8[rowstart8:rowend8]
        rowstart8 = rowend8 + 1 #Reset the  next index of last index as the next start index
        
        ts = int(dt.datetime.utcnow().timestamp()) #Get the timestamp
        
        #For data from each machine append the timestamp as well
        for i in newdata4:
            i["ts"] = ts
            data.append(i)  
        for i in newdata5:
            i["ts"] = ts
            data.append(i)
        for i in newdata6:
            i["ts"] = ts
            data.append(i)
        for i in newdata7:
            i["ts"] = ts
            data.append(i)
        for i in newdata8:
            i["ts"] = ts
            data.append(i)
           
        publish_message(producer, topic, data) #Publish X records alone
        
        data = [] #We will make the entire list again
        
        #Now we will repeat the above entire process to get Y random records from each machine and will publish it in the next iteration
        rowcounty4 = random.randint(0,5) #Getting random Y records for machine 4
        rowend4 = rowstart4 + rowcounty4 #Getting the end index
        if rowend4 > len(data4)-1: #If end index is greater than last index
            newdata4 = data4[rowstart4:len(data4)-1] #Take data till last index
            rowend4 = rowcounty4 - len(newdata4)-1 #get the number of how much more data we need from the start
            rowstart4 = 0 #Start from the first sequence again
            newcountdata4 = data4[rowstart4:rowend4] #Get the remaining data from the start
            for i in newcountdata4:
                newdata4.append(i)
        elif rowend4 == len(data4)-1:  #If end index becomes equal to the last index
            newdata4 = data4[rowstart4:rowend4]
            rowend4 = -1 #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata4 = data4[rowstart4:rowend4]
        rowstart4 = rowend4 + 1 #Reset the  next index of last index as the next start index
        
        rowcounty5 = random.randint(0,5) #Getting random Y records for machine 5
        rowend5 = rowstart5 + rowcounty5 #Getting the end index
        if rowend5 > len(data5)-1: #If end index is greater than last index
            newdata5 = data5[rowstart5:len(data5)-1] #Take data till last index
            rowend5 = rowcounty5 - len(newdata5)-1 #get the number of how much more data we need from the start
            rowstart5 = 0 #Start from the first sequence again
            newcountdata5 = data5[rowstart5:rowend5] #Get the remaining data from the start
            for i in newcountdata5:
                newdata5.append(i)
        elif rowend5 == len(data5)-1: #If end index becomes equal to the last index
            newdata5 = data5[rowstart5:rowend5]
            rowend5 = -1 #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata5 = data5[rowstart5:rowend5]
        rowstart5 = rowend5 + 1 #Reset the  next index of last index as the next start index 
        
        rowcounty6 = random.randint(0,5) #Getting random Y records for machine 6
        rowend6 = rowstart6 + rowcounty6 #Getting the end index
        if rowend6 > len(data6)-1: #If end index is greater than last index
            newdata6 = data6[rowstart6:len(data6)-1] #Take data till last index
            rowend6 = rowcounty6 - len(newdata6)-1 #get the number of how much more data we need from the start
            rowstart6 = 0 #Start from the first sequence again
            newcountdata6 = data6[rowstart6:rowend6] #Get the remaining data from the start
            for i in newcountdata6:
                newdata6.append(i)
        elif rowend6 == len(data6)-1: #If end index becomes equal to the last index
            newdata6 = data6[rowstart6:rowend6]
            rowend6 = -1 #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata6 = data6[rowstart6:rowend6]
        rowstart6 = rowend6 + 1 #Reset the  next index of last index as the next start index
        
        rowcounty7 = random.randint(0,5) #Getting random Y records for machine 7
        rowend7 = rowstart7 + rowcounty7 #Getting the end index
        if rowend7 > len(data7): #If end index is greater than last index
            newdata7 = data7[rowstart7:len(data7)-1] #Take data till last index
            rowend7 = rowcounty7 - len(newdata7)-1 #get the number of how much more data we need from the start
            rowstart7 = 0 #Start from the first sequence again
            newcountdata7 = data7[rowstart7:rowend7] #Get the remaining data from the start
            for i in new_count_data7:
                new_data7.append(i)
        elif rowend7 == len(data7)-1: #If end index becomes equal to the last index
            newdata7 = data7[rowstart7:rowend7] 
            rowend7 = -1 #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata7 = data7[rowstart7:rowend7]
        rowstart7 = rowend7 + 1 #Reset the  next index of last index as the next start index
        
        rowcounty8 = random.randint(0,5) #Getting random Y records for machine 7
        rowend8 = rowstart8 + rowcounty8 #Getting the end index
        if rowend8 > len(data8)-1: #If end index is greater than last index
            newdata8 = data8[rowstart8:len(data8)-1] #Take data till last index
            rowend8 = rowcounty8 - len(newdata8)-1 #get the number of how much more data we need from the start
            rowstart8 = 0 #Start from the first sequence again
            newcountdata8 = data8[rowstart8:rowend8] #Get the remaining data from the start
            for i in newcountdata8:
                newdata8.append(i)
        elif rowend8 == len(data8)-1: #If end index becomes equal to the last index
            newdata8 = data8[rowstart8:rowend8]
            rowend8 = -1  #Setting as -1 ,so in the next iteration we can start from zero
        else:
            newdata8 = data8[rowstart8:rowend8]
        rowstart8 = rowend8 + 1 #Reset the  next index of last index as the next start index
        
        #For data from each machine append the timestamp as well
        for i in newdata4:
            i["ts"] = ts
            data.append(i)  
        for i in newdata5:
            i["ts"] = ts
            data.append(i)
        for i in newdata6:
            i["ts"] = ts
            data.append(i)
        for i in newdata7:
            i["ts"] = ts
            data.append(i)
        for i in newdata8:
            i["ts"] = ts
            data.append(i)    
            
        sleep(10) #Wait for 10 seconds to start next cycle
# Out:
# Publishing records..
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# Message published successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-eaa11e7e87b2> in <module>
#     290             data.append(i)
#     291
# --> 292         sleep(10) #Wait for 10 seconds to start next cycle
#     293
#
# KeyboardInterrupt:
