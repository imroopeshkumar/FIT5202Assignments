# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt
import csv
import pandas as pd

# %%
def read_csv(fileName):
    data = []
    #WRITE THE CODE TO READ CSV FILE
    with open(fileName) as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data.append(row)
    return data

# %%
def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, data)
        print('Message published successfully. Data: ')
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))

# %%
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  value_serializer=lambda x: dumps(x).encode('ascii'),
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer

# %%
if __name__ == '__main__':
   
    topic = 'memory'
    cRows = read_csv('../Streaming_Linux_memory.csv')
    df = pd.DataFrame(cRows)
#     df.head()
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    m4,m5,m6,m7,m8 = [],[],[],[],[]
    for record in cRows: 
        if(record['machine'] == str(4)):
            m4.append(record)
        elif(record['machine'] == str(5)):
            m5.append(record)
        elif(record['machine'] == str(6)):
            m6.append(record)
        elif(record['machine'] == str(7)):
            m7.append(record)
        elif(record['machine'] == str(8)):
            m8.append(record)
    x4 = x5 = x6 = x7 = x8 = 0
    y4 = y5 = y6 = y7 = y8 = 0

    data = []
    while(True):
        ts = int(dt.datetime.utcnow().timestamp())
        try:
            randomint = random.randint(10,50)
            tempdata = m4[x4:x4 +randomint]
            for x in tempdata:
                x['ts'] = ts
            data +=(tempdata)
#             print(x4)
#             print(x)
            x4+=randomint

            randomint = random.randint(10,50)
            tempdata = m5[x5:x5 +randomint]
            for x in tempdata:
                x['ts'] = ts
            data+=(tempdata)
            x5+=randomint

            randomint = random.randint(10,50)
            tempdata = m6[x6:x6 +randomint]
            for x in tempdata:
                x['ts'] = ts
            data+=(tempdata)
            x6+=randomint

            randomint = random.randint(10,50)
            tempdata = m7[x7:x7 +randomint]
            for x in tempdata:
                x['ts'] = ts
            data+=(tempdata)
            x7+=randomint

            randomint = random.randint(10,50)
            tempdata = m8[x8:x8 +randomint]
            for x in tempdata:
                x['ts'] = ts
            data+=(tempdata)
            x8+=randomint
        except: 
            x4=x5=x6=x7=x8=0
            
        publish_message(producer, topic, data)
        data = []
        try:
            
            randomint = random.randint(10,50)
            tempdata = m4[y4:y4+randomint]
            for x in tempdata:
                x['ts'] = ts
            data+=(tempdata)
            y4+= randomint


            randomint = random.randint(10,50)
            tempdata = m5[y5:y5+randomint]
            for x in tempdata:
                x['ts'] = ts
            data+=(tempdata)
            y5+= randomint

            randomint = random.randint(10,50)
            tempdata = m6[y6:y6+randomint]
            for x in tempdata:
                x['ts'] = ts
            data+=(tempdata)
            y6+= randomint

            randomint = random.randint(10,50)
            tempdata = m7[y7:y7+randomint]
            for x in tempdata:
                x['ts'] = ts
            data+=(tempdata)
            y7+= randomint

            randomint = random.randint(10,50)
            tempdata = m8[y8:y8+randomint]
            for x in tempdata:
                x['ts'] = ts
            data+=(tempdata)
            y8+= randomint
        except: 
            y4=y5=y6=y7=y8=0
        print('published')
        sleep(5)

# %%
df.count()
